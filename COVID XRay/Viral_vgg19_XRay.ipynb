# %% [markdown]
# <a href="https://colab.research.google.com/github/nah16d/Deep-Learning-in-Malaria-and-Covid-Detection/blob/main/COVID%20XRay/Viral_vgg19_XRay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Feb  2 14:00:46 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
#define size to which images are to be resized
IMAGE_SIZE = [224, 224] # feel free to change depending on dataset

# training config:
epochs = 100
batch_size = 32

#define paths
viral_path = '/content/drive/MyDrive/COVID/Datasets/XRay/ViralPneumonia'
normal_path = '/content/drive/MyDrive/COVID/Datasets/XRay/Normal'

# Use glob to grab images from path .jpg or jpeg
viral_files = glob(viral_path + '/*')
normal_files = glob(normal_path + '/*')

# %%
# Visualize file variable contents
print("Total viral Files: ",len(viral_files))
print("Total Normal Files: ",len(normal_files))
# Out:
# Total viral Files:  412
# Total Normal Files:  880

# %%
# Fetch Images and Class Labels from Files
viral_labels = []
normal_labels = []

viral_images=[]
normal_images=[]

for i in range(len(viral_files)):
  image = cv2.imread(viral_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per kera
  image = cv2.resize(image,(224,224)) # resize as per model
  viral_images.append(image) # append image
  viral_labels.append('XRay_viral') # append class label
for i in range(len(normal_files)):
  image = cv2.imread(normal_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  normal_images.append(image)
  normal_labels.append('XRay_normal')

# %%
# look at a random image for fun
def plot_images(images, title):
    nrows, ncols = 3, 3
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(viral_images, 'Positive viral XRay')
plot_images(normal_images, 'Negative viral XRay')

# %%
# Convert to array and Normalize to interval of [0,1]
viral_images = np.array(viral_images) / 255
normal_images = np.array(normal_images) / 255

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# split into training and testing
viral_x_train, viral_x_test, viral_y_train, viral_y_test = train_test_split(
    viral_images, viral_labels, test_size=0.2)
normal_x_train, normal_x_test, normal_y_train, normal_y_test = train_test_split(
    normal_images, normal_labels, test_size=0.2)


X_train = np.concatenate((normal_x_train, viral_x_train), axis=0)
X_test = np.concatenate((normal_x_test, viral_x_test), axis=0)
y_train = np.concatenate((normal_y_train, viral_y_train), axis=0)
y_test = np.concatenate((normal_y_test, viral_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
# split into training and testing
viral_x_train, viral_x_test, viral_y_train, viral_y_test = train_test_split(
    viral_images, viral_labels, test_size=0.2)
normal_x_train, normal_x_test, normal_y_train, normal_y_test = train_test_split(
    normal_images, normal_labels, test_size=0.2)


X_train = np.concatenate((normal_x_train, viral_x_train), axis=0)
X_test = np.concatenate((normal_x_test, viral_x_test), axis=0)
y_train = np.concatenate((normal_y_train, viral_y_train), axis=0)
y_test = np.concatenate((normal_y_test, viral_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
plot_images(viral_x_train, 'X_train')
plot_images(viral_x_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing viral and normal for X_train and X_test

# %%
vgg = VGG19(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = vgg.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=vgg.input, outputs=outputs)

for layer in vgg.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
# Visualize Model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 50178
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %%
history = model.fit(train_aug.flow(X_train, y_train, batch_size=batch_size),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / batch_size,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=epochs)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 28s 582ms/step - loss: 1.0503 - accuracy: 0.6711 - val_loss: 0.2910 - val_accuracy: 0.8610
# Epoch 2/100
# 32/32 [==============================] - 17s 514ms/step - loss: 0.2695 - accuracy: 0.8930 - val_loss: 0.1824 - val_accuracy: 0.9344
# Epoch 3/100
# 32/32 [==============================] - 17s 510ms/step - loss: 0.2491 - accuracy: 0.9219 - val_loss: 0.4268 - val_accuracy: 0.8185
# Epoch 4/100
# 32/32 [==============================] - 16s 508ms/step - loss: 0.2516 - accuracy: 0.9224 - val_loss: 0.1673 - val_accuracy: 0.9421
# Epoch 5/100
# 32/32 [==============================] - 17s 509ms/step - loss: 0.2514 - accuracy: 0.9052 - val_loss: 0.1174 - val_accuracy: 0.9614
# Epoch 6/100
# 32/32 [==============================] - 16s 517ms/step - loss: 0.1682 - accuracy: 0.9339 - val_loss: 0.1319 - val_accuracy: 0.9537
# Epoch 7/100
# 32/32 [==============================] - 16s 508ms/step - loss: 0.1804 - accuracy: 0.9460 - val_loss: 0.1344 - val_accuracy: 0.9575
# Epoch 8/100
# 32/32 [==============================] - 17s 516ms/step - loss: 0.1509 - accuracy: 0.9496 - val_loss: 0.1025 - val_accuracy: 0.9653
# Epoch 9/100
# 32/32 [==============================] - 17s 521ms/step - loss: 0.1501 - accuracy: 0.9412 - val_loss: 0.0764 - val_accuracy: 0.9730
# Epoch 10/100
# 32/32 [==============================] - 17s 520ms/step - loss: 0.1719 - accuracy: 0.9486 - val_loss: 0.1143 - val_accuracy: 0.9575
# Epoch 11/100
# 32/32 [==============================] - 17s 519ms/step - loss: 0.1926 - accuracy: 0.9276 - val_loss: 0.0703 - val_accuracy: 0.9691
# Epoch 12/100
# 32/32 [==============================] - 17s 525ms/step - loss: 0.1752 - accuracy: 0.9460 - val_loss: 0.0750 - val_accuracy: 0.9730
# Epoch 13/100
# 32/32 [==============================] - 17s 519ms/step - loss: 0.1697 - accuracy: 0.9347 - val_loss: 0.0835 - val_accuracy: 0.9730
# Epoch 14/100
# 32/32 [==============================] - 16s 507ms/step - loss: 0.1417 - accuracy: 0.9495 - val_loss: 0.0834 - val_accuracy: 0.9730
# Epoch 15/100
# 32/32 [==============================] - 17s 513ms/step - loss: 0.1374 - accuracy: 0.9598 - val_loss: 0.0702 - val_accuracy: 0.9807
# Epoch 16/100
# 32/32 [==============================] - 16s 508ms/step - loss: 0.1504 - accuracy: 0.9355 - val_loss: 0.1738 - val_accuracy: 0.9344
# Epoch 17/100
# 32/32 [==============================] - 17s 515ms/step - loss: 0.2173 - accuracy: 0.9368 - val_loss: 0.0699 - val_accuracy: 0.9730
# Epoch 18/100
# 32/32 [==============================] - 16s 520ms/step - loss: 0.1800 - accuracy: 0.9365 - val_loss: 0.0741 - val_accuracy: 0.9768
# Epoch 19/100
# 32/32 [==============================] - 17s 519ms/step - loss: 0.1606 - accuracy: 0.9452 - val_loss: 0.1640 - val_accuracy: 0.9382
# Epoch 20/100
# 32/32 [==============================] - 16s 508ms/step - loss: 0.1406 - accuracy: 0.9552 - val_loss: 0.0580 - val_accuracy: 0.9807
# Epoch 21/100
# 32/32 [==============================] - 16s 507ms/step - loss: 0.1099 - accuracy: 0.9655 - val_loss: 0.0569 - val_accuracy: 0.9807
# Epoch 22/100
# 32/32 [==============================] - 16s 508ms/step - loss: 0.1333 - accuracy: 0.9451 - val_loss: 0.1106 - val_accuracy: 0.9537
# Epoch 23/100
# 32/32 [==============================] - 17s 512ms/step - loss: 0.1817 - accuracy: 0.9395 - val_loss: 0.0659 - val_accuracy: 0.9768
# Epoch 24/100
# 32/32 [==============================] - 17s 510ms/step - loss: 0.1431 - accuracy: 0.9511 - val_loss: 0.2110 - val_accuracy: 0.9073
# Epoch 25/100
# 32/32 [==============================] - 16s 501ms/step - loss: 0.0961 - accuracy: 0.9591 - val_loss: 0.0489 - val_accuracy: 0.9884
# Epoch 26/100
# 32/32 [==============================] - 16s 506ms/step - loss: 0.1393 - accuracy: 0.9567 - val_loss: 0.0493 - val_accuracy: 0.9768
# Epoch 27/100
# 32/32 [==============================] - 16s 501ms/step - loss: 0.1415 - accuracy: 0.9536 - val_loss: 0.0667 - val_accuracy: 0.9768
# Epoch 28/100
# 32/32 [==============================] - 16s 501ms/step - loss: 0.1881 - accuracy: 0.9341 - val_loss: 0.1711 - val_accuracy: 0.9228
# Epoch 29/100
# 32/32 [==============================] - 16s 504ms/step - loss: 0.1665 - accuracy: 0.9592 - val_loss: 0.0588 - val_accuracy: 0.9807
# Epoch 30/100
# 32/32 [==============================] - 16s 503ms/step - loss: 0.1552 - accuracy: 0.9470 - val_loss: 0.0919 - val_accuracy: 0.9653
# Epoch 31/100
# 32/32 [==============================] - 16s 509ms/step - loss: 0.1887 - accuracy: 0.9327 - val_loss: 0.0848 - val_accuracy: 0.9768
# Epoch 32/100
# 32/32 [==============================] - 16s 503ms/step - loss: 0.1335 - accuracy: 0.9543 - val_loss: 0.0584 - val_accuracy: 0.9807
# Epoch 33/100
# 32/32 [==============================] - 16s 500ms/step - loss: 0.1195 - accuracy: 0.9604 - val_loss: 0.1964 - val_accuracy: 0.9151
# Epoch 34/100
# 32/32 [==============================] - 16s 498ms/step - loss: 0.0969 - accuracy: 0.9674 - val_loss: 0.0584 - val_accuracy: 0.9807
# Epoch 35/100
# 32/32 [==============================] - 16s 493ms/step - loss: 0.1410 - accuracy: 0.9591 - val_loss: 0.0763 - val_accuracy: 0.9730
# Epoch 36/100
# 32/32 [==============================] - 16s 500ms/step - loss: 0.1574 - accuracy: 0.9494 - val_loss: 0.0544 - val_accuracy: 0.9807
# Epoch 37/100
# 32/32 [==============================] - 16s 498ms/step - loss: 0.1378 - accuracy: 0.9592 - val_loss: 0.0715 - val_accuracy: 0.9768
# Epoch 38/100
# 32/32 [==============================] - 16s 502ms/step - loss: 0.1360 - accuracy: 0.9506 - val_loss: 0.1941 - val_accuracy: 0.9228
# Epoch 39/100
# 32/32 [==============================] - 16s 500ms/step - loss: 0.1768 - accuracy: 0.9493 - val_loss: 0.0512 - val_accuracy: 0.9807
# Epoch 40/100
# 32/32 [==============================] - 16s 507ms/step - loss: 0.1163 - accuracy: 0.9658 - val_loss: 0.0488 - val_accuracy: 0.9807
# Epoch 41/100
# 32/32 [==============================] - 16s 503ms/step - loss: 0.1701 - accuracy: 0.9514 - val_loss: 0.0631 - val_accuracy: 0.9691
# Epoch 42/100
# 32/32 [==============================] - 16s 506ms/step - loss: 0.1479 - accuracy: 0.9500 - val_loss: 0.0598 - val_accuracy: 0.9653
# Epoch 43/100
# 32/32 [==============================] - 16s 508ms/step - loss: 0.0893 - accuracy: 0.9701 - val_loss: 0.0463 - val_accuracy: 0.9807
# Epoch 44/100
# 32/32 [==============================] - 16s 507ms/step - loss: 0.1484 - accuracy: 0.9581 - val_loss: 0.1247 - val_accuracy: 0.9575
# Epoch 45/100
# 32/32 [==============================] - 17s 508ms/step - loss: 0.1459 - accuracy: 0.9494 - val_loss: 0.1117 - val_accuracy: 0.9653
# Epoch 46/100
# 32/32 [==============================] - 17s 520ms/step - loss: 0.1984 - accuracy: 0.9180 - val_loss: 0.0521 - val_accuracy: 0.9768
# Epoch 47/100
# 32/32 [==============================] - 16s 503ms/step - loss: 0.1173 - accuracy: 0.9664 - val_loss: 0.0525 - val_accuracy: 0.9807
# Epoch 48/100
# 32/32 [==============================] - 16s 503ms/step - loss: 0.1475 - accuracy: 0.9509 - val_loss: 0.0767 - val_accuracy: 0.9807
# Epoch 49/100
# 32/32 [==============================] - 16s 501ms/step - loss: 0.1463 - accuracy: 0.9550 - val_loss: 0.0912 - val_accuracy: 0.9537
# Epoch 50/100
# 32/32 [==============================] - 16s 500ms/step - loss: 0.1930 - accuracy: 0.9458 - val_loss: 0.1419 - val_accuracy: 0.9459
# Epoch 51/100
# 32/32 [==============================] - 16s 505ms/step - loss: 0.1365 - accuracy: 0.9575 - val_loss: 0.0466 - val_accuracy: 0.9768
# Epoch 52/100
# 32/32 [==============================] - 16s 493ms/step - loss: 0.2108 - accuracy: 0.9309 - val_loss: 0.0969 - val_accuracy: 0.9730
# Epoch 53/100
# 32/32 [==============================] - 16s 496ms/step - loss: 0.1517 - accuracy: 0.9523 - val_loss: 0.0475 - val_accuracy: 0.9768
# Epoch 54/100
# 32/32 [==============================] - 16s 483ms/step - loss: 0.1786 - accuracy: 0.9520 - val_loss: 0.2007 - val_accuracy: 0.9305
# Epoch 55/100
# 32/32 [==============================] - 16s 482ms/step - loss: 0.2795 - accuracy: 0.9213 - val_loss: 0.0497 - val_accuracy: 0.9768
# Epoch 56/100
# 32/32 [==============================] - 16s 484ms/step - loss: 0.1558 - accuracy: 0.9516 - val_loss: 0.0460 - val_accuracy: 0.9730
# Epoch 57/100
# 32/32 [==============================] - 16s 490ms/step - loss: 0.1367 - accuracy: 0.9626 - val_loss: 0.0789 - val_accuracy: 0.9691
# Epoch 58/100
# 32/32 [==============================] - 16s 496ms/step - loss: 0.1227 - accuracy: 0.9643 - val_loss: 0.1904 - val_accuracy: 0.9344
# Epoch 59/100
# 32/32 [==============================] - 16s 504ms/step - loss: 0.1467 - accuracy: 0.9546 - val_loss: 0.0476 - val_accuracy: 0.9846
# Epoch 60/100
# 32/32 [==============================] - 16s 500ms/step - loss: 0.1114 - accuracy: 0.9726 - val_loss: 0.1294 - val_accuracy: 0.9459
# Epoch 61/100
# 32/32 [==============================] - 16s 502ms/step - loss: 0.1818 - accuracy: 0.9439 - val_loss: 0.1420 - val_accuracy: 0.9575
# Epoch 62/100
# 32/32 [==============================] - 16s 489ms/step - loss: 0.1215 - accuracy: 0.9524 - val_loss: 0.1393 - val_accuracy: 0.9537
# Epoch 63/100
# 32/32 [==============================] - 16s 490ms/step - loss: 0.1947 - accuracy: 0.9449 - val_loss: 0.0506 - val_accuracy: 0.9807
# Epoch 64/100
# 32/32 [==============================] - 16s 489ms/step - loss: 0.1185 - accuracy: 0.9638 - val_loss: 0.1346 - val_accuracy: 0.9575
# Epoch 65/100
# 32/32 [==============================] - 16s 485ms/step - loss: 0.4102 - accuracy: 0.9072 - val_loss: 0.0991 - val_accuracy: 0.9537
# Epoch 66/100
# 32/32 [==============================] - 15s 477ms/step - loss: 0.1626 - accuracy: 0.9499 - val_loss: 0.0594 - val_accuracy: 0.9768
# Epoch 67/100
# 32/32 [==============================] - 16s 480ms/step - loss: 0.1488 - accuracy: 0.9577 - val_loss: 0.0496 - val_accuracy: 0.9807
# Epoch 68/100
# 32/32 [==============================] - 16s 492ms/step - loss: 0.1167 - accuracy: 0.9651 - val_loss: 0.0554 - val_accuracy: 0.9807
# Epoch 69/100
# 32/32 [==============================] - 16s 479ms/step - loss: 0.1337 - accuracy: 0.9485 - val_loss: 0.0563 - val_accuracy: 0.9846
# Epoch 70/100
# 32/32 [==============================] - 15s 476ms/step - loss: 0.1258 - accuracy: 0.9569 - val_loss: 0.0544 - val_accuracy: 0.9846
# Epoch 71/100
# 32/32 [==============================] - 16s 485ms/step - loss: 0.1307 - accuracy: 0.9603 - val_loss: 0.1716 - val_accuracy: 0.9537
# Epoch 72/100
# 32/32 [==============================] - 16s 494ms/step - loss: 0.2018 - accuracy: 0.9411 - val_loss: 0.1118 - val_accuracy: 0.9653
# Epoch 73/100
# 32/32 [==============================] - 16s 496ms/step - loss: 0.1871 - accuracy: 0.9404 - val_loss: 0.0559 - val_accuracy: 0.9807
# Epoch 74/100
# 32/32 [==============================] - 16s 501ms/step - loss: 0.1581 - accuracy: 0.9452 - val_loss: 0.0998 - val_accuracy: 0.9730
# Epoch 75/100
# 32/32 [==============================] - 16s 504ms/step - loss: 0.1401 - accuracy: 0.9524 - val_loss: 0.1441 - val_accuracy: 0.9575
# Epoch 76/100
# 32/32 [==============================] - 16s 502ms/step - loss: 0.1731 - accuracy: 0.9479 - val_loss: 0.3122 - val_accuracy: 0.9112
# Epoch 77/100
# 32/32 [==============================] - 17s 510ms/step - loss: 0.1877 - accuracy: 0.9503 - val_loss: 0.0704 - val_accuracy: 0.9691
# Epoch 78/100
# 32/32 [==============================] - 17s 509ms/step - loss: 0.1380 - accuracy: 0.9596 - val_loss: 0.0545 - val_accuracy: 0.9846
# Epoch 79/100
# 32/32 [==============================] - 17s 512ms/step - loss: 0.0696 - accuracy: 0.9757 - val_loss: 0.0548 - val_accuracy: 0.9807
# Epoch 80/100
# 32/32 [==============================] - 17s 512ms/step - loss: 0.1224 - accuracy: 0.9632 - val_loss: 0.1001 - val_accuracy: 0.9459
# Epoch 81/100
# 32/32 [==============================] - 17s 515ms/step - loss: 0.1260 - accuracy: 0.9538 - val_loss: 0.0477 - val_accuracy: 0.9846
# Epoch 82/100
# 32/32 [==============================] - 17s 514ms/step - loss: 0.1479 - accuracy: 0.9576 - val_loss: 0.0945 - val_accuracy: 0.9730
# Epoch 83/100
# 32/32 [==============================] - 17s 516ms/step - loss: 0.1837 - accuracy: 0.9442 - val_loss: 0.0534 - val_accuracy: 0.9807
# Epoch 84/100
# 32/32 [==============================] - 17s 514ms/step - loss: 0.2388 - accuracy: 0.9455 - val_loss: 0.1772 - val_accuracy: 0.9498
# Epoch 85/100
# 32/32 [==============================] - 17s 515ms/step - loss: 0.3328 - accuracy: 0.9199 - val_loss: 0.2804 - val_accuracy: 0.9305
# Epoch 86/100
# 32/32 [==============================] - 17s 515ms/step - loss: 0.1338 - accuracy: 0.9639 - val_loss: 0.0962 - val_accuracy: 0.9730
# Epoch 87/100
# 32/32 [==============================] - 17s 519ms/step - loss: 0.1449 - accuracy: 0.9657 - val_loss: 0.0430 - val_accuracy: 0.9807
# Epoch 88/100
# 32/32 [==============================] - 17s 516ms/step - loss: 0.2015 - accuracy: 0.9632 - val_loss: 0.0620 - val_accuracy: 0.9730
# Epoch 89/100
# 32/32 [==============================] - 17s 512ms/step - loss: 0.1502 - accuracy: 0.9609 - val_loss: 0.1974 - val_accuracy: 0.9498
# Epoch 90/100
# 32/32 [==============================] - 17s 512ms/step - loss: 0.2325 - accuracy: 0.9351 - val_loss: 1.2304 - val_accuracy: 0.7568
# Epoch 91/100
# 32/32 [==============================] - 16s 506ms/step - loss: 0.4958 - accuracy: 0.8935 - val_loss: 0.1542 - val_accuracy: 0.9691
# Epoch 92/100
# 32/32 [==============================] - 16s 505ms/step - loss: 0.1481 - accuracy: 0.9637 - val_loss: 0.0486 - val_accuracy: 0.9768
# Epoch 93/100
# 32/32 [==============================] - 16s 509ms/step - loss: 0.1216 - accuracy: 0.9659 - val_loss: 0.0785 - val_accuracy: 0.9768
# Epoch 94/100
# 32/32 [==============================] - 17s 514ms/step - loss: 0.0801 - accuracy: 0.9706 - val_loss: 0.0641 - val_accuracy: 0.9768
# Epoch 95/100
# 32/32 [==============================] - 17s 514ms/step - loss: 0.1447 - accuracy: 0.9652 - val_loss: 0.0536 - val_accuracy: 0.9730
# Epoch 96/100
# 32/32 [==============================] - 17s 524ms/step - loss: 0.1856 - accuracy: 0.9537 - val_loss: 0.0639 - val_accuracy: 0.9691
# Epoch 97/100
# 32/32 [==============================] - 17s 516ms/step - loss: 0.1699 - accuracy: 0.9568 - val_loss: 0.0948 - val_accuracy: 0.9614
# Epoch 98/100
# 32/32 [==============================] - 17s 513ms/step - loss: 0.1766 - accuracy: 0.9550 - val_loss: 0.0644 - val_accuracy: 0.9846
# Epoch 99/100
# 32/32 [==============================] - 17s 509ms/step - loss: 0.1729 - accuracy: 0.9503 - val_loss: 0.0543 - val_accuracy: 0.9807
# Epoch 100/100
# 32/32 [==============================] - 17s 522ms/step - loss: 0.1132 - accuracy: 0.9607 - val_loss: 0.1206 - val_accuracy: 0.9691

# %%
# Save Model and Weights
model.save('Viral_vgg19_XRay.h5')
model.save_weights('Viral_vgg19_XRay.hdf5')

# %%
import tensorflow as tf
from tensorflow import keras
tf.keras.models.save_model(model, '/content/drive/MyDrive/COVID/Viral_vgg19_XRay.h5')
tf.keras.models.save_model(model, '/content/drive/MyDrive/COVID/Viral_vgg19_XRay.hdf5')

# %%
# Load saved model
model = load_model('/content/drive/MyDrive/COVID/Viral_vgg19_XRay.h5')

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% viral')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% normal')
  plt.style.reload_library
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
def plot_confusion_matrix(normalize):
  classes = ['viral','normal']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       176
#            1       1.00      0.90      0.95        83
#
#     accuracy                           0.97       259
#    macro avg       0.98      0.95      0.96       259
# weighted avg       0.97      0.97      0.97       259

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('Viral_vgg19_XRay_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('Viral_vgg19_XRay_loss.png')
plt.show()

# %%
#ACCURACY
from sklearn.metrics import accuracy_score
print('Accuracy score:' , accuracy_score(y_test_bin, y_pred_bin))
# Out:
# Accuracy score: 0.9691119691119691
