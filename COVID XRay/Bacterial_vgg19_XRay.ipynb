# %% [markdown]
# <a href="https://colab.research.google.com/github/nah16d/Deep-Learning-in-Malaria-and-Covid-Detection/blob/main/COVID%20XRay/Bacterial_vgg19_XRay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Feb  5 15:48:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
#define size to which images are to be resized
IMAGE_SIZE = [224, 224] # feel free to change depending on dataset

# training config:
epochs = 100
batch_size = 32

#define paths
bacterial_path = '/content/drive/MyDrive/COVID/Datasets/XRay/BacterialPneumonia'
normal_path = '/content/drive/MyDrive/COVID/Datasets/XRay/Normal'

# Use glob to grab images from path .jpg or jpeg
bacterial_files = glob(bacterial_path + '/*')
normal_files = glob(normal_path + '/*')

# %%
# Visualize file variable contents
print("Total bacterial Files: ",len(bacterial_files))
print("Total Normal Files: ",len(normal_files))
# Out:
# Total bacterial Files:  650
# Total Normal Files:  880

# %%
# Fetch Images and Class Labels from Files
bacterial_labels = []
normal_labels = []

bacterial_images=[]
normal_images=[]

for i in range(len(bacterial_files)):
  image = cv2.imread(bacterial_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per kera
  image = cv2.resize(image,(224,224)) # resize as per model
  bacterial_images.append(image) # append image
  bacterial_labels.append('XRay_bacterial') # append class label
for i in range(len(normal_files)):
  image = cv2.imread(normal_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  normal_images.append(image)
  normal_labels.append('XRay_normal')

# %%
# look at a random image for fun
def plot_images(images, title):
    nrows, ncols = 3, 3
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(bacterial_images, 'Positive bacterial XRay')
plot_images(normal_images, 'Negative bacterial XRay')

# %%
# Convert to array and Normalize to interval of [0,1]
bacterial_images = np.array(bacterial_images) / 255
normal_images = np.array(normal_images) / 255

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# split into training and testing
bacterial_x_train, bacterial_x_test, bacterial_y_train, bacterial_y_test = train_test_split(
    bacterial_images, bacterial_labels, test_size=0.2)
normal_x_train, normal_x_test, normal_y_train, normal_y_test = train_test_split(
    normal_images, normal_labels, test_size=0.2)


X_train = np.concatenate((normal_x_train, bacterial_x_train), axis=0)
X_test = np.concatenate((normal_x_test, bacterial_x_test), axis=0)
y_train = np.concatenate((normal_y_train, bacterial_y_train), axis=0)
y_test = np.concatenate((normal_y_test, bacterial_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
# split into training and testing
bacterial_x_train, bacterial_x_test, bacterial_y_train, bacterial_y_test = train_test_split(
    bacterial_images, bacterial_labels, test_size=0.2)
normal_x_train, normal_x_test, normal_y_train, normal_y_test = train_test_split(
    normal_images, normal_labels, test_size=0.2)


X_train = np.concatenate((normal_x_train, bacterial_x_train), axis=0)
X_test = np.concatenate((normal_x_test, bacterial_x_test), axis=0)
y_train = np.concatenate((normal_y_train, bacterial_y_train), axis=0)
y_test = np.concatenate((normal_y_test, bacterial_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
plot_images(bacterial_x_train, 'X_train')
plot_images(bacterial_x_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing bacterial and normal for X_train and X_test

# %%
vgg = VGG19(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = vgg.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=vgg.input, outputs=outputs)

for layer in vgg.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step

# %%
# Visualize Model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 50178
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %%
history = model.fit(train_aug.flow(X_train, y_train, batch_size=batch_size),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / batch_size,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=epochs)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 24s 411ms/step - loss: 0.4727 - accuracy: 0.7751 - val_loss: 0.2909 - val_accuracy: 0.8856
# Epoch 2/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.1884 - accuracy: 0.9206 - val_loss: 0.1160 - val_accuracy: 0.9444
# Epoch 3/100
# 38/38 [==============================] - 15s 382ms/step - loss: 0.1796 - accuracy: 0.9427 - val_loss: 0.1179 - val_accuracy: 0.9542
# Epoch 4/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1136 - accuracy: 0.9607 - val_loss: 0.0959 - val_accuracy: 0.9608
# Epoch 5/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1534 - accuracy: 0.9454 - val_loss: 0.1569 - val_accuracy: 0.9444
# Epoch 6/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0969 - accuracy: 0.9616 - val_loss: 0.0815 - val_accuracy: 0.9608
# Epoch 7/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.1085 - accuracy: 0.9576 - val_loss: 0.0746 - val_accuracy: 0.9641
# Epoch 8/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.0944 - accuracy: 0.9720 - val_loss: 0.0745 - val_accuracy: 0.9608
# Epoch 9/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1053 - accuracy: 0.9613 - val_loss: 0.0915 - val_accuracy: 0.9641
# Epoch 10/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.1195 - accuracy: 0.9547 - val_loss: 0.1049 - val_accuracy: 0.9575
# Epoch 11/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.1321 - accuracy: 0.9520 - val_loss: 0.0952 - val_accuracy: 0.9673
# Epoch 12/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.0982 - accuracy: 0.9629 - val_loss: 0.0727 - val_accuracy: 0.9542
# Epoch 13/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0580 - accuracy: 0.9723 - val_loss: 0.0665 - val_accuracy: 0.9641
# Epoch 14/100
# 38/38 [==============================] - 15s 392ms/step - loss: 0.0814 - accuracy: 0.9742 - val_loss: 0.0772 - val_accuracy: 0.9641
# Epoch 15/100
# 38/38 [==============================] - 15s 389ms/step - loss: 0.0733 - accuracy: 0.9783 - val_loss: 0.0951 - val_accuracy: 0.9542
# Epoch 16/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.0701 - accuracy: 0.9654 - val_loss: 0.0726 - val_accuracy: 0.9575
# Epoch 17/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.1031 - accuracy: 0.9646 - val_loss: 0.1794 - val_accuracy: 0.9412
# Epoch 18/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.1135 - accuracy: 0.9613 - val_loss: 0.0686 - val_accuracy: 0.9608
# Epoch 19/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.0529 - accuracy: 0.9772 - val_loss: 0.0668 - val_accuracy: 0.9771
# Epoch 20/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.0771 - accuracy: 0.9722 - val_loss: 0.0935 - val_accuracy: 0.9673
# Epoch 21/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.1087 - accuracy: 0.9639 - val_loss: 0.0917 - val_accuracy: 0.9673
# Epoch 22/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.0897 - accuracy: 0.9744 - val_loss: 0.2551 - val_accuracy: 0.9118
# Epoch 23/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.1025 - accuracy: 0.9715 - val_loss: 0.0601 - val_accuracy: 0.9673
# Epoch 24/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.1354 - accuracy: 0.9514 - val_loss: 0.3240 - val_accuracy: 0.8987
# Epoch 25/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.1343 - accuracy: 0.9694 - val_loss: 0.0859 - val_accuracy: 0.9673
# Epoch 26/100
# 38/38 [==============================] - 15s 394ms/step - loss: 0.0806 - accuracy: 0.9758 - val_loss: 0.0878 - val_accuracy: 0.9673
# Epoch 27/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.1106 - accuracy: 0.9666 - val_loss: 0.1838 - val_accuracy: 0.9379
# Epoch 28/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.0891 - accuracy: 0.9632 - val_loss: 0.1902 - val_accuracy: 0.9379
# Epoch 29/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0965 - accuracy: 0.9706 - val_loss: 0.1041 - val_accuracy: 0.9641
# Epoch 30/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.0928 - accuracy: 0.9794 - val_loss: 0.1035 - val_accuracy: 0.9608
# Epoch 31/100
# 38/38 [==============================] - 15s 389ms/step - loss: 0.0593 - accuracy: 0.9803 - val_loss: 0.0642 - val_accuracy: 0.9673
# Epoch 32/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.0640 - accuracy: 0.9785 - val_loss: 0.0614 - val_accuracy: 0.9673
# Epoch 33/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0847 - accuracy: 0.9699 - val_loss: 0.2683 - val_accuracy: 0.9183
# Epoch 34/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.0594 - accuracy: 0.9814 - val_loss: 0.0613 - val_accuracy: 0.9706
# Epoch 35/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.0547 - accuracy: 0.9770 - val_loss: 0.0900 - val_accuracy: 0.9641
# Epoch 36/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0701 - accuracy: 0.9796 - val_loss: 0.1234 - val_accuracy: 0.9608
# Epoch 37/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.1149 - accuracy: 0.9666 - val_loss: 0.1656 - val_accuracy: 0.9477
# Epoch 38/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.0794 - accuracy: 0.9662 - val_loss: 0.0655 - val_accuracy: 0.9706
# Epoch 39/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1106 - accuracy: 0.9661 - val_loss: 0.1269 - val_accuracy: 0.9608
# Epoch 40/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.0601 - accuracy: 0.9752 - val_loss: 0.0833 - val_accuracy: 0.9706
# Epoch 41/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.1051 - accuracy: 0.9695 - val_loss: 0.0561 - val_accuracy: 0.9771
# Epoch 42/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0737 - accuracy: 0.9781 - val_loss: 0.3193 - val_accuracy: 0.9052
# Epoch 43/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.1159 - accuracy: 0.9650 - val_loss: 0.0778 - val_accuracy: 0.9575
# Epoch 44/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0772 - accuracy: 0.9787 - val_loss: 0.0685 - val_accuracy: 0.9641
# Epoch 45/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0623 - accuracy: 0.9815 - val_loss: 0.0586 - val_accuracy: 0.9771
# Epoch 46/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0594 - accuracy: 0.9794 - val_loss: 0.0890 - val_accuracy: 0.9641
# Epoch 47/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.0566 - accuracy: 0.9799 - val_loss: 0.0681 - val_accuracy: 0.9739
# Epoch 48/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.0677 - accuracy: 0.9746 - val_loss: 0.1412 - val_accuracy: 0.9575
# Epoch 49/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0491 - accuracy: 0.9839 - val_loss: 0.0801 - val_accuracy: 0.9641
# Epoch 50/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0766 - accuracy: 0.9755 - val_loss: 0.0664 - val_accuracy: 0.9706
# Epoch 51/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.0516 - accuracy: 0.9779 - val_loss: 0.1317 - val_accuracy: 0.9575
# Epoch 52/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.0549 - accuracy: 0.9776 - val_loss: 0.1724 - val_accuracy: 0.9510
# Epoch 53/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.0409 - accuracy: 0.9822 - val_loss: 0.0813 - val_accuracy: 0.9641
# Epoch 54/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.0927 - accuracy: 0.9755 - val_loss: 0.2721 - val_accuracy: 0.9183
# Epoch 55/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1522 - accuracy: 0.9586 - val_loss: 0.1080 - val_accuracy: 0.9641
# Epoch 56/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.0960 - accuracy: 0.9773 - val_loss: 0.0604 - val_accuracy: 0.9739
# Epoch 57/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.0602 - accuracy: 0.9810 - val_loss: 0.0572 - val_accuracy: 0.9739
# Epoch 58/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0664 - accuracy: 0.9817 - val_loss: 0.1316 - val_accuracy: 0.9641
# Epoch 59/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0935 - accuracy: 0.9796 - val_loss: 0.0577 - val_accuracy: 0.9706
# Epoch 60/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0641 - accuracy: 0.9733 - val_loss: 0.0614 - val_accuracy: 0.9706
# Epoch 61/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.0620 - accuracy: 0.9808 - val_loss: 0.0821 - val_accuracy: 0.9739
# Epoch 62/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.0446 - accuracy: 0.9880 - val_loss: 0.0773 - val_accuracy: 0.9804
# Epoch 63/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.0675 - accuracy: 0.9808 - val_loss: 0.1545 - val_accuracy: 0.9575
# Epoch 64/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0721 - accuracy: 0.9765 - val_loss: 0.0920 - val_accuracy: 0.9706
# Epoch 65/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0884 - accuracy: 0.9795 - val_loss: 0.3586 - val_accuracy: 0.9085
# Epoch 66/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1425 - accuracy: 0.9762 - val_loss: 0.0634 - val_accuracy: 0.9739
# Epoch 67/100
# 38/38 [==============================] - 15s 392ms/step - loss: 0.0712 - accuracy: 0.9793 - val_loss: 0.1756 - val_accuracy: 0.9477
# Epoch 68/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.0612 - accuracy: 0.9813 - val_loss: 0.3118 - val_accuracy: 0.9183
# Epoch 69/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1706 - accuracy: 0.9533 - val_loss: 0.0351 - val_accuracy: 0.9837
# Epoch 70/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.1195 - accuracy: 0.9716 - val_loss: 0.0459 - val_accuracy: 0.9706
# Epoch 71/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.0692 - accuracy: 0.9775 - val_loss: 0.1841 - val_accuracy: 0.9542
# Epoch 72/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1022 - accuracy: 0.9726 - val_loss: 0.0455 - val_accuracy: 0.9804
# Epoch 73/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.1299 - accuracy: 0.9666 - val_loss: 0.1148 - val_accuracy: 0.9641
# Epoch 74/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0561 - accuracy: 0.9818 - val_loss: 0.1552 - val_accuracy: 0.9510
# Epoch 75/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.0556 - accuracy: 0.9791 - val_loss: 0.0459 - val_accuracy: 0.9739
# Epoch 76/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.0943 - accuracy: 0.9767 - val_loss: 0.3212 - val_accuracy: 0.9118
# Epoch 77/100
# 38/38 [==============================] - 15s 389ms/step - loss: 0.1641 - accuracy: 0.9566 - val_loss: 0.5676 - val_accuracy: 0.8758
# Epoch 78/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.2261 - accuracy: 0.9569 - val_loss: 0.0488 - val_accuracy: 0.9837
# Epoch 79/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0791 - accuracy: 0.9781 - val_loss: 0.0538 - val_accuracy: 0.9771
# Epoch 80/100
# 38/38 [==============================] - 15s 386ms/step - loss: 0.0961 - accuracy: 0.9755 - val_loss: 0.1014 - val_accuracy: 0.9673
# Epoch 81/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.0912 - accuracy: 0.9674 - val_loss: 0.2107 - val_accuracy: 0.9510
# Epoch 82/100
# 38/38 [==============================] - 15s 382ms/step - loss: 0.0711 - accuracy: 0.9842 - val_loss: 0.0543 - val_accuracy: 0.9771
# Epoch 83/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0342 - accuracy: 0.9876 - val_loss: 0.1123 - val_accuracy: 0.9641
# Epoch 84/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0787 - accuracy: 0.9769 - val_loss: 0.1319 - val_accuracy: 0.9575
# Epoch 85/100
# 38/38 [==============================] - 15s 382ms/step - loss: 0.0864 - accuracy: 0.9734 - val_loss: 0.0401 - val_accuracy: 0.9804
# Epoch 86/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0393 - accuracy: 0.9877 - val_loss: 0.1136 - val_accuracy: 0.9706
# Epoch 87/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0723 - accuracy: 0.9829 - val_loss: 0.0659 - val_accuracy: 0.9706
# Epoch 88/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.0762 - accuracy: 0.9803 - val_loss: 0.0403 - val_accuracy: 0.9771
# Epoch 89/100
# 38/38 [==============================] - 15s 381ms/step - loss: 0.0739 - accuracy: 0.9751 - val_loss: 0.0462 - val_accuracy: 0.9804
# Epoch 90/100
# 38/38 [==============================] - 15s 381ms/step - loss: 0.0692 - accuracy: 0.9796 - val_loss: 0.0775 - val_accuracy: 0.9771
# Epoch 91/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.2386 - accuracy: 0.9542 - val_loss: 0.2583 - val_accuracy: 0.9412
# Epoch 92/100
# 38/38 [==============================] - 15s 390ms/step - loss: 0.0886 - accuracy: 0.9786 - val_loss: 0.2658 - val_accuracy: 0.9379
# Epoch 93/100
# 38/38 [==============================] - 15s 381ms/step - loss: 0.0925 - accuracy: 0.9775 - val_loss: 0.2190 - val_accuracy: 0.9542
# Epoch 94/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1673 - accuracy: 0.9603 - val_loss: 0.0484 - val_accuracy: 0.9804
# Epoch 95/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.1164 - accuracy: 0.9665 - val_loss: 0.0651 - val_accuracy: 0.9739
# Epoch 96/100
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0396 - accuracy: 0.9867 - val_loss: 0.1393 - val_accuracy: 0.9608
# Epoch 97/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.1111 - accuracy: 0.9704 - val_loss: 0.0535 - val_accuracy: 0.9771
# Epoch 98/100
# 38/38 [==============================] - 15s 387ms/step - loss: 0.1154 - accuracy: 0.9695 - val_loss: 0.0878 - val_accuracy: 0.9706
# Epoch 99/100
# 38/38 [==============================] - 15s 385ms/step - loss: 0.0925 - accuracy: 0.9856 - val_loss: 0.0520 - val_accuracy: 0.9804
# Epoch 100/100
# 38/38 [==============================] - 15s 392ms/step - loss: 0.2097 - accuracy: 0.9546 - val_loss: 0.2368 - val_accuracy: 0.9542

# %%
# Save Model and Weights
model.save('bacterial_vgg19_XRay.h5')
model.save_weights('bacterial_vgg19_XRay.hdf5')

# %%
import tensorflow as tf
from tensorflow import keras
tf.keras.models.save_model(model, '/content/drive/MyDrive/COVID/bacterial_vgg19_XRay.h5')
tf.keras.models.save_model(model, '/content/drive/MyDrive/COVID/bacterial_vgg19_XRay.hdf5')

# %%
# Load saved model
model = load_model('/content/drive/MyDrive/COVID/bacterial_vgg19_XRay.h5')

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% bacterial')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% normal')
  plt.style.reload_library
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
def plot_confusion_matrix(normalize):
  classes = ['bacterial','normal']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94       130
#            1       0.93      1.00      0.96       176
#
#     accuracy                           0.95       306
#    macro avg       0.96      0.95      0.95       306
# weighted avg       0.96      0.95      0.95       306

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('bacterial_vgg19_XRay_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('bacterial_vgg19_XRay_loss.png')
plt.show()

# %%
#ACCURACY
from sklearn.metrics import accuracy_score
print('Accuracy score:' , accuracy_score(y_test_bin, y_pred_bin))
# Out:
# Accuracy score: 0.954248366013072
