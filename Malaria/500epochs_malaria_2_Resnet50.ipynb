# %% [markdown]
# <a href="https://colab.research.google.com/github/nah16d/Deep-Learning-in-Malaria-and-Covid-Detection/blob/main/Malaria/500epochs_malaria_2_Resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Jan 11 19:43:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
#define size to which images are to be resized
IMAGE_SIZE = [224, 224] 

# training config:
epochs = 500
batch_size = 32

#define paths
parasite_path = '/content/drive/MyDrive/cell_images_3/Parasite'
uninfected_path = '/content/drive/MyDrive/cell_images_3/Uninfected'

# Use glob to grab images from path .jpg or jpeg
parasite_files = glob(parasite_path + '/*')
uninfected_files = glob(uninfected_path + '/*')

# %%
# Visualize file variable contents
print("Total Count: ",len(parasite_files))
print("Total Count: ",len(uninfected_files))
# Out:
# Total Count:  321
# Total Count:  214

# %%
# Fetch Images and Class Labels from Files
parasite_labels = []
uninfected_labels = []

parasite_images=[]
uninfected_images=[]

for i in range(len(parasite_files)):
  image = cv2.imread(parasite_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per kera
  image = cv2.resize(image,(224,224)) # resize as per model
  parasite_images.append(image) # append image
  parasite_labels.append('parasite') # append class label
for i in range(len(uninfected_files)):
  image = cv2.imread(uninfected_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  uninfected_images.append(image)
  uninfected_labels.append('uninfected')

# %%
# look at a random image for fun
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(parasite_images, 'Positive Malaria sample')
plot_images(uninfected_images, 'Negative Malaria sample')

# %%
# Convert to array and Normalize to interval of [0,1]
parasite_images = np.array(parasite_images) / 255
uninfected_images = np.array(uninfected_images) / 255

# %%
# split into training and testing
parasite_x_train, parasite_x_test, parasite_y_train, parasite_y_test = train_test_split(
    parasite_images, parasite_labels, test_size=0.2)
uninfected_x_train, uninfected_x_test, uninfected_y_train, uninfected_y_test = train_test_split(
    uninfected_images, uninfected_labels, test_size=0.2)


X_train = np.concatenate((uninfected_x_train, parasite_x_train), axis=0)
X_test = np.concatenate((uninfected_x_test, parasite_x_test), axis=0)
y_train = np.concatenate((uninfected_y_train, parasite_y_train), axis=0)
y_test = np.concatenate((uninfected_y_test, parasite_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
plot_images(parasite_x_train, 'X_train')
plot_images(parasite_x_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing parasite and uninfected for X_train and X_test

# %%
resnet = ResNet50(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = resnet.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=resnet.input, outputs=outputs)

for layer in resnet.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step

# %%
# Visualize Model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100352)       0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100352)       0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            200706      dropout[0][0]
# ==================================================================================================
# Total params: 23,788,418
# Trainable params: 200,706
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %%
history = model.fit(train_aug.flow(X_train, y_train, batch_size=batch_size),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / batch_size,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=epochs)
# Out:
# Epoch 1/500
# 13/13 [==============================] - 15s 456ms/step - loss: 4.2038 - accuracy: 0.5018 - val_loss: 3.0821 - val_accuracy: 0.3981
# Epoch 2/500
# 13/13 [==============================] - 5s 364ms/step - loss: 2.3103 - accuracy: 0.4572 - val_loss: 1.3089 - val_accuracy: 0.6019
# Epoch 3/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.6523 - accuracy: 0.4819 - val_loss: 1.2191 - val_accuracy: 0.6019
# Epoch 4/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.4058 - accuracy: 0.5842 - val_loss: 0.9010 - val_accuracy: 0.4074
# Epoch 5/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.1223 - accuracy: 0.5228 - val_loss: 0.6286 - val_accuracy: 0.5833
# Epoch 6/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.0216 - accuracy: 0.5483 - val_loss: 0.6539 - val_accuracy: 0.5926
# Epoch 7/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.2694 - accuracy: 0.5943 - val_loss: 0.6259 - val_accuracy: 0.7130
# Epoch 8/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.2580 - accuracy: 0.4922 - val_loss: 1.4908 - val_accuracy: 0.3981
# Epoch 9/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.3009 - accuracy: 0.5450 - val_loss: 0.6232 - val_accuracy: 0.6574
# Epoch 10/500
# 13/13 [==============================] - 5s 358ms/step - loss: 0.9219 - accuracy: 0.5854 - val_loss: 0.6123 - val_accuracy: 0.6944
# Epoch 11/500
# 13/13 [==============================] - 5s 365ms/step - loss: 0.9087 - accuracy: 0.5848 - val_loss: 1.2612 - val_accuracy: 0.3981
# Epoch 12/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.9743 - accuracy: 0.5868 - val_loss: 0.6692 - val_accuracy: 0.5833
# Epoch 13/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.3145 - accuracy: 0.5076 - val_loss: 0.8610 - val_accuracy: 0.4815
# Epoch 14/500
# 13/13 [==============================] - 5s 358ms/step - loss: 1.1997 - accuracy: 0.5372 - val_loss: 0.5910 - val_accuracy: 0.7222
# Epoch 15/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9471 - accuracy: 0.5975 - val_loss: 0.6160 - val_accuracy: 0.6389
# Epoch 16/500
# 13/13 [==============================] - 5s 368ms/step - loss: 0.8718 - accuracy: 0.5722 - val_loss: 1.9859 - val_accuracy: 0.3981
# Epoch 17/500
# 13/13 [==============================] - 5s 368ms/step - loss: 1.5702 - accuracy: 0.4991 - val_loss: 1.9568 - val_accuracy: 0.3981
# Epoch 18/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.3014 - accuracy: 0.5189 - val_loss: 1.5519 - val_accuracy: 0.3981
# Epoch 19/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.4329 - accuracy: 0.5578 - val_loss: 1.7837 - val_accuracy: 0.3981
# Epoch 20/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.6211 - accuracy: 0.5628 - val_loss: 0.7514 - val_accuracy: 0.5648
# Epoch 21/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.5216 - accuracy: 0.5304 - val_loss: 1.5483 - val_accuracy: 0.6019
# Epoch 22/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.8985 - accuracy: 0.5186 - val_loss: 0.7083 - val_accuracy: 0.6204
# Epoch 23/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.9832 - accuracy: 0.6039 - val_loss: 0.7580 - val_accuracy: 0.6019
# Epoch 24/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.9909 - accuracy: 0.5844 - val_loss: 0.6577 - val_accuracy: 0.6481
# Epoch 25/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.1594 - accuracy: 0.5556 - val_loss: 0.9054 - val_accuracy: 0.5000
# Epoch 26/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.7817 - accuracy: 0.6349 - val_loss: 0.6538 - val_accuracy: 0.6759
# Epoch 27/500
# 13/13 [==============================] - 5s 380ms/step - loss: 0.9313 - accuracy: 0.6057 - val_loss: 0.5512 - val_accuracy: 0.7593
# Epoch 28/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0198 - accuracy: 0.5562 - val_loss: 0.7870 - val_accuracy: 0.5556
# Epoch 29/500
# 13/13 [==============================] - 5s 358ms/step - loss: 0.9603 - accuracy: 0.5985 - val_loss: 0.5693 - val_accuracy: 0.7593
# Epoch 30/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.8263 - accuracy: 0.6084 - val_loss: 0.6459 - val_accuracy: 0.6574
# Epoch 31/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.8945 - accuracy: 0.5864 - val_loss: 0.7149 - val_accuracy: 0.6111
# Epoch 32/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.8448 - accuracy: 0.6347 - val_loss: 1.2045 - val_accuracy: 0.4259
# Epoch 33/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.9489 - accuracy: 0.6109 - val_loss: 0.6472 - val_accuracy: 0.6574
# Epoch 34/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0863 - accuracy: 0.5709 - val_loss: 1.0259 - val_accuracy: 0.4722
# Epoch 35/500
# 13/13 [==============================] - 5s 364ms/step - loss: 0.9686 - accuracy: 0.6165 - val_loss: 0.5741 - val_accuracy: 0.6944
# Epoch 36/500
# 13/13 [==============================] - 5s 365ms/step - loss: 0.9271 - accuracy: 0.5930 - val_loss: 1.0190 - val_accuracy: 0.4444
# Epoch 37/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.7969 - accuracy: 0.6401 - val_loss: 0.6995 - val_accuracy: 0.6296
# Epoch 38/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1431 - accuracy: 0.5657 - val_loss: 0.5893 - val_accuracy: 0.7037
# Epoch 39/500
# 13/13 [==============================] - 5s 359ms/step - loss: 0.9774 - accuracy: 0.6215 - val_loss: 0.7775 - val_accuracy: 0.5926
# Epoch 40/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.2832 - accuracy: 0.5774 - val_loss: 0.5651 - val_accuracy: 0.7500
# Epoch 41/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.3772 - accuracy: 0.5193 - val_loss: 0.9846 - val_accuracy: 0.4815
# Epoch 42/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.9806 - accuracy: 0.5676 - val_loss: 0.6574 - val_accuracy: 0.6574
# Epoch 43/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.7842 - accuracy: 0.5786 - val_loss: 0.8032 - val_accuracy: 0.5833
# Epoch 44/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.9968 - accuracy: 0.5137 - val_loss: 2.6738 - val_accuracy: 0.3981
# Epoch 45/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.5227 - accuracy: 0.5988 - val_loss: 1.0540 - val_accuracy: 0.5000
# Epoch 46/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0608 - accuracy: 0.6188 - val_loss: 0.8234 - val_accuracy: 0.5741
# Epoch 47/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.2505 - accuracy: 0.5873 - val_loss: 0.6539 - val_accuracy: 0.6667
# Epoch 48/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0746 - accuracy: 0.6692 - val_loss: 0.5596 - val_accuracy: 0.7500
# Epoch 49/500
# 13/13 [==============================] - 5s 358ms/step - loss: 1.0273 - accuracy: 0.6131 - val_loss: 0.6940 - val_accuracy: 0.6296
# Epoch 50/500
# 13/13 [==============================] - 5s 385ms/step - loss: 1.1533 - accuracy: 0.6082 - val_loss: 1.6713 - val_accuracy: 0.3981
# Epoch 51/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.3349 - accuracy: 0.5457 - val_loss: 0.5520 - val_accuracy: 0.7500
# Epoch 52/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.2753 - accuracy: 0.5700 - val_loss: 0.8919 - val_accuracy: 0.5926
# Epoch 53/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.2949 - accuracy: 0.5781 - val_loss: 0.6022 - val_accuracy: 0.6944
# Epoch 54/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1064 - accuracy: 0.5814 - val_loss: 0.5638 - val_accuracy: 0.7407
# Epoch 55/500
# 13/13 [==============================] - 5s 358ms/step - loss: 0.8263 - accuracy: 0.7098 - val_loss: 0.5720 - val_accuracy: 0.7407
# Epoch 56/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.1014 - accuracy: 0.5788 - val_loss: 1.2632 - val_accuracy: 0.6019
# Epoch 57/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.4151 - accuracy: 0.5820 - val_loss: 1.2376 - val_accuracy: 0.6019
# Epoch 58/500
# 13/13 [==============================] - 5s 358ms/step - loss: 1.1193 - accuracy: 0.6625 - val_loss: 0.5991 - val_accuracy: 0.7315
# Epoch 59/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0293 - accuracy: 0.5508 - val_loss: 0.5715 - val_accuracy: 0.7685
# Epoch 60/500
# 13/13 [==============================] - 5s 358ms/step - loss: 0.9515 - accuracy: 0.6490 - val_loss: 1.3404 - val_accuracy: 0.6019
# Epoch 61/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.5136 - accuracy: 0.5783 - val_loss: 0.5892 - val_accuracy: 0.7407
# Epoch 62/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8719 - accuracy: 0.6442 - val_loss: 0.6538 - val_accuracy: 0.6667
# Epoch 63/500
# 13/13 [==============================] - 5s 359ms/step - loss: 0.9247 - accuracy: 0.6517 - val_loss: 1.0620 - val_accuracy: 0.6019
# Epoch 64/500
# 13/13 [==============================] - 5s 357ms/step - loss: 1.4198 - accuracy: 0.5514 - val_loss: 0.5508 - val_accuracy: 0.7593
# Epoch 65/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0233 - accuracy: 0.5936 - val_loss: 0.7644 - val_accuracy: 0.5833
# Epoch 66/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.8741 - accuracy: 0.6523 - val_loss: 0.6682 - val_accuracy: 0.6204
# Epoch 67/500
# 13/13 [==============================] - 5s 380ms/step - loss: 0.9548 - accuracy: 0.6137 - val_loss: 0.5430 - val_accuracy: 0.7315
# Epoch 68/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0436 - accuracy: 0.6143 - val_loss: 0.9180 - val_accuracy: 0.5556
# Epoch 69/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0255 - accuracy: 0.5932 - val_loss: 0.8824 - val_accuracy: 0.5463
# Epoch 70/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0306 - accuracy: 0.5881 - val_loss: 0.7749 - val_accuracy: 0.6111
# Epoch 71/500
# 13/13 [==============================] - 5s 392ms/step - loss: 0.7136 - accuracy: 0.7066 - val_loss: 0.8257 - val_accuracy: 0.5741
# Epoch 72/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.0579 - accuracy: 0.6083 - val_loss: 0.5176 - val_accuracy: 0.7778
# Epoch 73/500
# 13/13 [==============================] - 5s 369ms/step - loss: 0.9289 - accuracy: 0.6398 - val_loss: 0.5517 - val_accuracy: 0.7315
# Epoch 74/500
# 13/13 [==============================] - 5s 377ms/step - loss: 0.8639 - accuracy: 0.6065 - val_loss: 1.3120 - val_accuracy: 0.4259
# Epoch 75/500
# 13/13 [==============================] - 5s 372ms/step - loss: 1.0365 - accuracy: 0.6113 - val_loss: 0.5524 - val_accuracy: 0.7407
# Epoch 76/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.2718 - accuracy: 0.6014 - val_loss: 0.9294 - val_accuracy: 0.5926
# Epoch 77/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.1078 - accuracy: 0.6221 - val_loss: 2.4000 - val_accuracy: 0.3981
# Epoch 78/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.3608 - accuracy: 0.5619 - val_loss: 0.8829 - val_accuracy: 0.5926
# Epoch 79/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.2506 - accuracy: 0.5854 - val_loss: 0.6965 - val_accuracy: 0.6574
# Epoch 80/500
# 13/13 [==============================] - 5s 370ms/step - loss: 1.6375 - accuracy: 0.5450 - val_loss: 1.4872 - val_accuracy: 0.6019
# Epoch 81/500
# 13/13 [==============================] - 5s 370ms/step - loss: 1.7256 - accuracy: 0.5561 - val_loss: 1.5528 - val_accuracy: 0.6019
# Epoch 82/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.3828 - accuracy: 0.6109 - val_loss: 0.6168 - val_accuracy: 0.7130
# Epoch 83/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1129 - accuracy: 0.6024 - val_loss: 0.8119 - val_accuracy: 0.6204
# Epoch 84/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0436 - accuracy: 0.6346 - val_loss: 1.4488 - val_accuracy: 0.4352
# Epoch 85/500
# 13/13 [==============================] - 5s 364ms/step - loss: 0.9639 - accuracy: 0.6545 - val_loss: 0.5259 - val_accuracy: 0.7685
# Epoch 86/500
# 13/13 [==============================] - 5s 387ms/step - loss: 1.1669 - accuracy: 0.6139 - val_loss: 0.6594 - val_accuracy: 0.6481
# Epoch 87/500
# 13/13 [==============================] - 5s 370ms/step - loss: 1.1500 - accuracy: 0.5951 - val_loss: 1.0507 - val_accuracy: 0.6019
# Epoch 88/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.4376 - accuracy: 0.5763 - val_loss: 0.5853 - val_accuracy: 0.7407
# Epoch 89/500
# 13/13 [==============================] - 5s 364ms/step - loss: 0.9356 - accuracy: 0.6359 - val_loss: 2.2386 - val_accuracy: 0.3981
# Epoch 90/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.5409 - accuracy: 0.5469 - val_loss: 0.6258 - val_accuracy: 0.7130
# Epoch 91/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.9128 - accuracy: 0.6519 - val_loss: 0.5478 - val_accuracy: 0.7593
# Epoch 92/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.2175 - accuracy: 0.5890 - val_loss: 0.5404 - val_accuracy: 0.7407
# Epoch 93/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0935 - accuracy: 0.5969 - val_loss: 1.1807 - val_accuracy: 0.4907
# Epoch 94/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0174 - accuracy: 0.6117 - val_loss: 0.7574 - val_accuracy: 0.6204
# Epoch 95/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.2297 - accuracy: 0.6300 - val_loss: 1.8346 - val_accuracy: 0.3889
# Epoch 96/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.2026 - accuracy: 0.6122 - val_loss: 1.4268 - val_accuracy: 0.4537
# Epoch 97/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0900 - accuracy: 0.6543 - val_loss: 0.5624 - val_accuracy: 0.7685
# Epoch 98/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.8893 - accuracy: 0.6330 - val_loss: 1.5360 - val_accuracy: 0.4352
# Epoch 99/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.3046 - accuracy: 0.5431 - val_loss: 1.9823 - val_accuracy: 0.3889
# Epoch 100/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.4446 - accuracy: 0.5707 - val_loss: 1.2152 - val_accuracy: 0.4815
# Epoch 101/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.0126 - accuracy: 0.6016 - val_loss: 0.8967 - val_accuracy: 0.5926
# Epoch 102/500
# 13/13 [==============================] - 5s 367ms/step - loss: 0.9977 - accuracy: 0.6259 - val_loss: 0.6661 - val_accuracy: 0.6481
# Epoch 103/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.1009 - accuracy: 0.5608 - val_loss: 0.8202 - val_accuracy: 0.6111
# Epoch 104/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.0100 - accuracy: 0.6529 - val_loss: 0.5218 - val_accuracy: 0.7778
# Epoch 105/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9750 - accuracy: 0.6387 - val_loss: 1.2206 - val_accuracy: 0.6019
# Epoch 106/500
# 13/13 [==============================] - 5s 386ms/step - loss: 1.1836 - accuracy: 0.6324 - val_loss: 0.5983 - val_accuracy: 0.7222
# Epoch 107/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0331 - accuracy: 0.6237 - val_loss: 0.5494 - val_accuracy: 0.7407
# Epoch 108/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.1703 - accuracy: 0.5873 - val_loss: 0.5315 - val_accuracy: 0.7963
# Epoch 109/500
# 13/13 [==============================] - 5s 383ms/step - loss: 1.0216 - accuracy: 0.6148 - val_loss: 0.5378 - val_accuracy: 0.7685
# Epoch 110/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.9282 - accuracy: 0.6682 - val_loss: 0.5625 - val_accuracy: 0.7500
# Epoch 111/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9401 - accuracy: 0.6376 - val_loss: 0.5071 - val_accuracy: 0.7593
# Epoch 112/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0710 - accuracy: 0.6259 - val_loss: 0.5372 - val_accuracy: 0.7407
# Epoch 113/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.9187 - accuracy: 0.6900 - val_loss: 0.7244 - val_accuracy: 0.6574
# Epoch 114/500
# 13/13 [==============================] - 5s 381ms/step - loss: 1.0797 - accuracy: 0.6466 - val_loss: 0.6295 - val_accuracy: 0.6852
# Epoch 115/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.9168 - accuracy: 0.6422 - val_loss: 0.4961 - val_accuracy: 0.7963
# Epoch 116/500
# 13/13 [==============================] - 5s 359ms/step - loss: 0.9518 - accuracy: 0.6086 - val_loss: 0.7297 - val_accuracy: 0.6389
# Epoch 117/500
# 13/13 [==============================] - 5s 386ms/step - loss: 0.7974 - accuracy: 0.6503 - val_loss: 0.5639 - val_accuracy: 0.7778
# Epoch 118/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.0697 - accuracy: 0.6330 - val_loss: 0.4961 - val_accuracy: 0.7685
# Epoch 119/500
# 13/13 [==============================] - 5s 367ms/step - loss: 1.0892 - accuracy: 0.6228 - val_loss: 0.6989 - val_accuracy: 0.6852
# Epoch 120/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.1321 - accuracy: 0.6142 - val_loss: 0.5132 - val_accuracy: 0.7685
# Epoch 121/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.9129 - accuracy: 0.6329 - val_loss: 1.3358 - val_accuracy: 0.4722
# Epoch 122/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.2108 - accuracy: 0.5684 - val_loss: 0.5652 - val_accuracy: 0.7685
# Epoch 123/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.3798 - accuracy: 0.5746 - val_loss: 0.5276 - val_accuracy: 0.7500
# Epoch 124/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.7854 - accuracy: 0.6652 - val_loss: 0.5826 - val_accuracy: 0.7130
# Epoch 125/500
# 13/13 [==============================] - 5s 366ms/step - loss: 0.7399 - accuracy: 0.6741 - val_loss: 0.5328 - val_accuracy: 0.7500
# Epoch 126/500
# 13/13 [==============================] - 5s 390ms/step - loss: 0.9002 - accuracy: 0.6328 - val_loss: 0.6726 - val_accuracy: 0.6852
# Epoch 127/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.2595 - accuracy: 0.5798 - val_loss: 0.4956 - val_accuracy: 0.7685
# Epoch 128/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8546 - accuracy: 0.6687 - val_loss: 0.5239 - val_accuracy: 0.7500
# Epoch 129/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0251 - accuracy: 0.6258 - val_loss: 1.0764 - val_accuracy: 0.5278
# Epoch 130/500
# 13/13 [==============================] - 5s 359ms/step - loss: 0.9302 - accuracy: 0.6223 - val_loss: 0.5338 - val_accuracy: 0.7685
# Epoch 131/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.0105 - accuracy: 0.6071 - val_loss: 2.0324 - val_accuracy: 0.3889
# Epoch 132/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0142 - accuracy: 0.6282 - val_loss: 0.8335 - val_accuracy: 0.5833
# Epoch 133/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0665 - accuracy: 0.5652 - val_loss: 0.9456 - val_accuracy: 0.5648
# Epoch 134/500
# 13/13 [==============================] - 5s 367ms/step - loss: 0.9255 - accuracy: 0.6327 - val_loss: 1.0795 - val_accuracy: 0.5185
# Epoch 135/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.9546 - accuracy: 0.6361 - val_loss: 0.6512 - val_accuracy: 0.6667
# Epoch 136/500
# 13/13 [==============================] - 5s 374ms/step - loss: 0.9842 - accuracy: 0.6086 - val_loss: 0.5229 - val_accuracy: 0.7963
# Epoch 137/500
# 13/13 [==============================] - 5s 368ms/step - loss: 1.2012 - accuracy: 0.6371 - val_loss: 1.5993 - val_accuracy: 0.6019
# Epoch 138/500
# 13/13 [==============================] - 5s 383ms/step - loss: 1.5778 - accuracy: 0.6388 - val_loss: 0.5380 - val_accuracy: 0.7222
# Epoch 139/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.9129 - accuracy: 0.6443 - val_loss: 0.4870 - val_accuracy: 0.7963
# Epoch 140/500
# 13/13 [==============================] - 5s 381ms/step - loss: 1.1739 - accuracy: 0.6041 - val_loss: 0.5009 - val_accuracy: 0.7870
# Epoch 141/500
# 13/13 [==============================] - 5s 356ms/step - loss: 1.0913 - accuracy: 0.6523 - val_loss: 1.3793 - val_accuracy: 0.6019
# Epoch 142/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.3554 - accuracy: 0.6183 - val_loss: 0.7089 - val_accuracy: 0.6574
# Epoch 143/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.1361 - accuracy: 0.6361 - val_loss: 1.0245 - val_accuracy: 0.5926
# Epoch 144/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.4893 - accuracy: 0.5687 - val_loss: 0.9545 - val_accuracy: 0.6204
# Epoch 145/500
# 13/13 [==============================] - 5s 367ms/step - loss: 1.6456 - accuracy: 0.5596 - val_loss: 0.6284 - val_accuracy: 0.7130
# Epoch 146/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.4450 - accuracy: 0.5782 - val_loss: 0.5283 - val_accuracy: 0.7870
# Epoch 147/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.2031 - accuracy: 0.5946 - val_loss: 0.9921 - val_accuracy: 0.5926
# Epoch 148/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0804 - accuracy: 0.6107 - val_loss: 0.6212 - val_accuracy: 0.7222
# Epoch 149/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0723 - accuracy: 0.5870 - val_loss: 1.6004 - val_accuracy: 0.4815
# Epoch 150/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.3013 - accuracy: 0.5986 - val_loss: 0.6587 - val_accuracy: 0.6944
# Epoch 151/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.1528 - accuracy: 0.6377 - val_loss: 0.5423 - val_accuracy: 0.7685
# Epoch 152/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.5927 - accuracy: 0.6149 - val_loss: 0.5765 - val_accuracy: 0.7315
# Epoch 153/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.5057 - accuracy: 0.6048 - val_loss: 0.5666 - val_accuracy: 0.7963
# Epoch 154/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0939 - accuracy: 0.6514 - val_loss: 0.7694 - val_accuracy: 0.6667
# Epoch 155/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0652 - accuracy: 0.6122 - val_loss: 0.9828 - val_accuracy: 0.6111
# Epoch 156/500
# 13/13 [==============================] - 5s 359ms/step - loss: 0.9183 - accuracy: 0.6787 - val_loss: 0.5263 - val_accuracy: 0.7685
# Epoch 157/500
# 13/13 [==============================] - 5s 382ms/step - loss: 1.2716 - accuracy: 0.6146 - val_loss: 0.9575 - val_accuracy: 0.6111
# Epoch 158/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.7777 - accuracy: 0.5953 - val_loss: 0.8449 - val_accuracy: 0.6481
# Epoch 159/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.3111 - accuracy: 0.5876 - val_loss: 0.6641 - val_accuracy: 0.7407
# Epoch 160/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.1891 - accuracy: 0.6141 - val_loss: 0.8121 - val_accuracy: 0.6481
# Epoch 161/500
# 13/13 [==============================] - 5s 383ms/step - loss: 1.2805 - accuracy: 0.5829 - val_loss: 0.5296 - val_accuracy: 0.7778
# Epoch 162/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8773 - accuracy: 0.6721 - val_loss: 0.5770 - val_accuracy: 0.7500
# Epoch 163/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9590 - accuracy: 0.6629 - val_loss: 0.5274 - val_accuracy: 0.7778
# Epoch 164/500
# 13/13 [==============================] - 5s 386ms/step - loss: 0.9849 - accuracy: 0.6587 - val_loss: 0.5116 - val_accuracy: 0.7778
# Epoch 165/500
# 13/13 [==============================] - 5s 364ms/step - loss: 0.9102 - accuracy: 0.6855 - val_loss: 0.6638 - val_accuracy: 0.6759
# Epoch 166/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0169 - accuracy: 0.6515 - val_loss: 0.5159 - val_accuracy: 0.7778
# Epoch 167/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.9723 - accuracy: 0.6543 - val_loss: 0.8514 - val_accuracy: 0.6296
# Epoch 168/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.4150 - accuracy: 0.5998 - val_loss: 0.5133 - val_accuracy: 0.7778
# Epoch 169/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.2948 - accuracy: 0.5948 - val_loss: 0.6467 - val_accuracy: 0.6944
# Epoch 170/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.9863 - accuracy: 0.5383 - val_loss: 2.4590 - val_accuracy: 0.6019
# Epoch 171/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.9960 - accuracy: 0.6132 - val_loss: 0.5884 - val_accuracy: 0.7407
# Epoch 172/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.8634 - accuracy: 0.6640 - val_loss: 0.7429 - val_accuracy: 0.6944
# Epoch 173/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.3789 - accuracy: 0.6008 - val_loss: 0.8813 - val_accuracy: 0.6111
# Epoch 174/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9852 - accuracy: 0.6655 - val_loss: 0.9297 - val_accuracy: 0.6204
# Epoch 175/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.9419 - accuracy: 0.6457 - val_loss: 0.9717 - val_accuracy: 0.5833
# Epoch 176/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.2511 - accuracy: 0.6083 - val_loss: 1.4312 - val_accuracy: 0.4722
# Epoch 177/500
# 13/13 [==============================] - 5s 382ms/step - loss: 1.1918 - accuracy: 0.6019 - val_loss: 1.3580 - val_accuracy: 0.4815
# Epoch 178/500
# 13/13 [==============================] - 5s 368ms/step - loss: 1.5956 - accuracy: 0.5816 - val_loss: 1.8197 - val_accuracy: 0.4444
# Epoch 179/500
# 13/13 [==============================] - 5s 380ms/step - loss: 1.1293 - accuracy: 0.5960 - val_loss: 1.1142 - val_accuracy: 0.5463
# Epoch 180/500
# 13/13 [==============================] - 5s 380ms/step - loss: 0.7600 - accuracy: 0.7219 - val_loss: 1.2464 - val_accuracy: 0.5278
# Epoch 181/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.8869 - accuracy: 0.6528 - val_loss: 1.2309 - val_accuracy: 0.5370
# Epoch 182/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.2017 - accuracy: 0.6138 - val_loss: 0.6826 - val_accuracy: 0.7037
# Epoch 183/500
# 13/13 [==============================] - 5s 364ms/step - loss: 0.8771 - accuracy: 0.6600 - val_loss: 1.2094 - val_accuracy: 0.5370
# Epoch 184/500
# 13/13 [==============================] - 5s 364ms/step - loss: 0.9891 - accuracy: 0.6362 - val_loss: 0.5465 - val_accuracy: 0.7685
# Epoch 185/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0484 - accuracy: 0.6628 - val_loss: 0.5141 - val_accuracy: 0.7685
# Epoch 186/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.1736 - accuracy: 0.6665 - val_loss: 0.5465 - val_accuracy: 0.7778
# Epoch 187/500
# 13/13 [==============================] - 5s 380ms/step - loss: 0.8896 - accuracy: 0.6831 - val_loss: 0.7232 - val_accuracy: 0.6852
# Epoch 188/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.8775 - accuracy: 0.6749 - val_loss: 1.2697 - val_accuracy: 0.5185
# Epoch 189/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0271 - accuracy: 0.6300 - val_loss: 0.5209 - val_accuracy: 0.8056
# Epoch 190/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.1199 - accuracy: 0.6554 - val_loss: 0.5259 - val_accuracy: 0.7870
# Epoch 191/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.0275 - accuracy: 0.6084 - val_loss: 0.6939 - val_accuracy: 0.6944
# Epoch 192/500
# 13/13 [==============================] - 5s 358ms/step - loss: 0.9605 - accuracy: 0.6349 - val_loss: 0.7845 - val_accuracy: 0.6667
# Epoch 193/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9197 - accuracy: 0.6261 - val_loss: 0.5957 - val_accuracy: 0.7407
# Epoch 194/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1733 - accuracy: 0.6606 - val_loss: 0.5078 - val_accuracy: 0.7778
# Epoch 195/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9404 - accuracy: 0.6275 - val_loss: 0.5057 - val_accuracy: 0.7778
# Epoch 196/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8699 - accuracy: 0.6888 - val_loss: 0.4961 - val_accuracy: 0.7963
# Epoch 197/500
# 13/13 [==============================] - 5s 358ms/step - loss: 0.9382 - accuracy: 0.6437 - val_loss: 0.5366 - val_accuracy: 0.7963
# Epoch 198/500
# 13/13 [==============================] - 5s 367ms/step - loss: 0.9721 - accuracy: 0.6959 - val_loss: 0.5039 - val_accuracy: 0.7778
# Epoch 199/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0128 - accuracy: 0.6282 - val_loss: 1.5595 - val_accuracy: 0.4722
# Epoch 200/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.0904 - accuracy: 0.6429 - val_loss: 2.1102 - val_accuracy: 0.3981
# Epoch 201/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.3878 - accuracy: 0.5964 - val_loss: 0.9569 - val_accuracy: 0.5833
# Epoch 202/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0106 - accuracy: 0.6624 - val_loss: 0.8909 - val_accuracy: 0.6111
# Epoch 203/500
# 13/13 [==============================] - 5s 358ms/step - loss: 1.1919 - accuracy: 0.6594 - val_loss: 0.5255 - val_accuracy: 0.7407
# Epoch 204/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8658 - accuracy: 0.6714 - val_loss: 0.7726 - val_accuracy: 0.6574
# Epoch 205/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8188 - accuracy: 0.6695 - val_loss: 0.5788 - val_accuracy: 0.7500
# Epoch 206/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.3197 - accuracy: 0.5863 - val_loss: 1.1327 - val_accuracy: 0.5370
# Epoch 207/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.2751 - accuracy: 0.6468 - val_loss: 0.5548 - val_accuracy: 0.7500
# Epoch 208/500
# 13/13 [==============================] - 5s 370ms/step - loss: 1.0698 - accuracy: 0.6539 - val_loss: 0.7503 - val_accuracy: 0.6481
# Epoch 209/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.2218 - accuracy: 0.6026 - val_loss: 2.0051 - val_accuracy: 0.4074
# Epoch 210/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.6935 - accuracy: 0.5787 - val_loss: 0.6391 - val_accuracy: 0.7222
# Epoch 211/500
# 13/13 [==============================] - 5s 358ms/step - loss: 1.5448 - accuracy: 0.6045 - val_loss: 0.5108 - val_accuracy: 0.8056
# Epoch 212/500
# 13/13 [==============================] - 5s 355ms/step - loss: 1.1585 - accuracy: 0.6199 - val_loss: 0.9249 - val_accuracy: 0.6111
# Epoch 213/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.4890 - accuracy: 0.5905 - val_loss: 0.5552 - val_accuracy: 0.7407
# Epoch 214/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8667 - accuracy: 0.6823 - val_loss: 0.5220 - val_accuracy: 0.7407
# Epoch 215/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.3380 - accuracy: 0.5466 - val_loss: 0.8974 - val_accuracy: 0.5556
# Epoch 216/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0088 - accuracy: 0.6237 - val_loss: 0.8600 - val_accuracy: 0.5926
# Epoch 217/500
# 13/13 [==============================] - 5s 384ms/step - loss: 0.9566 - accuracy: 0.6389 - val_loss: 1.9909 - val_accuracy: 0.4074
# Epoch 218/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.1054 - accuracy: 0.6614 - val_loss: 0.6882 - val_accuracy: 0.6852
# Epoch 219/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.8563 - accuracy: 0.6956 - val_loss: 0.8278 - val_accuracy: 0.6204
# Epoch 220/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.1409 - accuracy: 0.6163 - val_loss: 0.6822 - val_accuracy: 0.7037
# Epoch 221/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0810 - accuracy: 0.6415 - val_loss: 1.1916 - val_accuracy: 0.6019
# Epoch 222/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.3815 - accuracy: 0.6395 - val_loss: 0.6951 - val_accuracy: 0.7037
# Epoch 223/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.4122 - accuracy: 0.5962 - val_loss: 0.5223 - val_accuracy: 0.7500
# Epoch 224/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8447 - accuracy: 0.6823 - val_loss: 0.5134 - val_accuracy: 0.8148
# Epoch 225/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9582 - accuracy: 0.6392 - val_loss: 0.5151 - val_accuracy: 0.7870
# Epoch 226/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0095 - accuracy: 0.6223 - val_loss: 0.7325 - val_accuracy: 0.6944
# Epoch 227/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.9770 - accuracy: 0.6848 - val_loss: 0.5712 - val_accuracy: 0.7870
# Epoch 228/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.1248 - accuracy: 0.6240 - val_loss: 1.4755 - val_accuracy: 0.4907
# Epoch 229/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9380 - accuracy: 0.7143 - val_loss: 2.5406 - val_accuracy: 0.3889
# Epoch 230/500
# 13/13 [==============================] - 5s 370ms/step - loss: 1.3742 - accuracy: 0.5705 - val_loss: 0.5956 - val_accuracy: 0.7407
# Epoch 231/500
# 13/13 [==============================] - 5s 382ms/step - loss: 1.0485 - accuracy: 0.6583 - val_loss: 0.6931 - val_accuracy: 0.7037
# Epoch 232/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0655 - accuracy: 0.6073 - val_loss: 0.5118 - val_accuracy: 0.7963
# Epoch 233/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.1882 - accuracy: 0.6359 - val_loss: 0.9211 - val_accuracy: 0.6019
# Epoch 234/500
# 13/13 [==============================] - 5s 386ms/step - loss: 1.2041 - accuracy: 0.6015 - val_loss: 0.8754 - val_accuracy: 0.6389
# Epoch 235/500
# 13/13 [==============================] - 5s 381ms/step - loss: 1.1851 - accuracy: 0.6441 - val_loss: 0.5301 - val_accuracy: 0.7500
# Epoch 236/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.8829 - accuracy: 0.7150 - val_loss: 0.5430 - val_accuracy: 0.7593
# Epoch 237/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.9979 - accuracy: 0.6620 - val_loss: 0.6211 - val_accuracy: 0.7315
# Epoch 238/500
# 13/13 [==============================] - 5s 381ms/step - loss: 0.9904 - accuracy: 0.6653 - val_loss: 1.5316 - val_accuracy: 0.4907
# Epoch 239/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.1213 - accuracy: 0.6154 - val_loss: 1.2397 - val_accuracy: 0.5463
# Epoch 240/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.1055 - accuracy: 0.6146 - val_loss: 1.2707 - val_accuracy: 0.5370
# Epoch 241/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0093 - accuracy: 0.6463 - val_loss: 0.7018 - val_accuracy: 0.7037
# Epoch 242/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.8200 - accuracy: 0.7012 - val_loss: 1.1517 - val_accuracy: 0.5463
# Epoch 243/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.0555 - accuracy: 0.6471 - val_loss: 0.5953 - val_accuracy: 0.7778
# Epoch 244/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.9838 - accuracy: 0.6512 - val_loss: 0.5433 - val_accuracy: 0.7870
# Epoch 245/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.1555 - accuracy: 0.6410 - val_loss: 0.6922 - val_accuracy: 0.7222
# Epoch 246/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.9909 - accuracy: 0.6518 - val_loss: 0.7861 - val_accuracy: 0.6944
# Epoch 247/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.2297 - accuracy: 0.6153 - val_loss: 1.1133 - val_accuracy: 0.5741
# Epoch 248/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.3156 - accuracy: 0.5881 - val_loss: 1.9722 - val_accuracy: 0.4537
# Epoch 249/500
# 13/13 [==============================] - 5s 384ms/step - loss: 1.2928 - accuracy: 0.6217 - val_loss: 0.6305 - val_accuracy: 0.7315
# Epoch 250/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.9017 - accuracy: 0.6663 - val_loss: 1.0223 - val_accuracy: 0.5741
# Epoch 251/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0334 - accuracy: 0.6546 - val_loss: 0.7247 - val_accuracy: 0.6852
# Epoch 252/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.8219 - accuracy: 0.6987 - val_loss: 0.5348 - val_accuracy: 0.7593
# Epoch 253/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.4286 - accuracy: 0.5978 - val_loss: 1.2371 - val_accuracy: 0.5556
# Epoch 254/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.5477 - accuracy: 0.5529 - val_loss: 2.0001 - val_accuracy: 0.4259
# Epoch 255/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.2156 - accuracy: 0.6032 - val_loss: 1.0960 - val_accuracy: 0.5833
# Epoch 256/500
# 13/13 [==============================] - 5s 366ms/step - loss: 0.9301 - accuracy: 0.6728 - val_loss: 0.6605 - val_accuracy: 0.7222
# Epoch 257/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.7765 - accuracy: 0.6944 - val_loss: 1.0433 - val_accuracy: 0.6019
# Epoch 258/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9399 - accuracy: 0.6855 - val_loss: 1.1164 - val_accuracy: 0.5833
# Epoch 259/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.3489 - accuracy: 0.6010 - val_loss: 1.0309 - val_accuracy: 0.5741
# Epoch 260/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1521 - accuracy: 0.6360 - val_loss: 0.7956 - val_accuracy: 0.6759
# Epoch 261/500
# 13/13 [==============================] - 5s 370ms/step - loss: 1.0109 - accuracy: 0.6679 - val_loss: 0.9128 - val_accuracy: 0.6574
# Epoch 262/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.6668 - accuracy: 0.6282 - val_loss: 2.2310 - val_accuracy: 0.4352
# Epoch 263/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.4571 - accuracy: 0.5704 - val_loss: 3.6998 - val_accuracy: 0.3981
# Epoch 264/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.6812 - accuracy: 0.6166 - val_loss: 1.6918 - val_accuracy: 0.4815
# Epoch 265/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.1057 - accuracy: 0.6428 - val_loss: 0.9197 - val_accuracy: 0.6019
# Epoch 266/500
# 13/13 [==============================] - 5s 367ms/step - loss: 0.9537 - accuracy: 0.6293 - val_loss: 1.0810 - val_accuracy: 0.6111
# Epoch 267/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.3488 - accuracy: 0.6186 - val_loss: 0.9590 - val_accuracy: 0.6019
# Epoch 268/500
# 13/13 [==============================] - 5s 365ms/step - loss: 0.8568 - accuracy: 0.6885 - val_loss: 2.9440 - val_accuracy: 0.3889
# Epoch 269/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.3837 - accuracy: 0.6188 - val_loss: 0.9049 - val_accuracy: 0.6296
# Epoch 270/500
# 13/13 [==============================] - 5s 368ms/step - loss: 0.9828 - accuracy: 0.6200 - val_loss: 0.9510 - val_accuracy: 0.6667
# Epoch 271/500
# 13/13 [==============================] - 5s 371ms/step - loss: 1.3959 - accuracy: 0.6240 - val_loss: 0.7657 - val_accuracy: 0.7130
# Epoch 272/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.2282 - accuracy: 0.6546 - val_loss: 0.5293 - val_accuracy: 0.7778
# Epoch 273/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0344 - accuracy: 0.6693 - val_loss: 2.0092 - val_accuracy: 0.4444
# Epoch 274/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.1640 - accuracy: 0.6176 - val_loss: 0.5203 - val_accuracy: 0.7963
# Epoch 275/500
# 13/13 [==============================] - 5s 358ms/step - loss: 1.3498 - accuracy: 0.6477 - val_loss: 0.6345 - val_accuracy: 0.7037
# Epoch 276/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.2957 - accuracy: 0.5826 - val_loss: 1.0414 - val_accuracy: 0.5833
# Epoch 277/500
# 13/13 [==============================] - 5s 384ms/step - loss: 0.9850 - accuracy: 0.6729 - val_loss: 1.0708 - val_accuracy: 0.6019
# Epoch 278/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0789 - accuracy: 0.6415 - val_loss: 1.0046 - val_accuracy: 0.6019
# Epoch 279/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.9746 - accuracy: 0.6257 - val_loss: 1.0976 - val_accuracy: 0.5926
# Epoch 280/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.8466 - accuracy: 0.6909 - val_loss: 0.9965 - val_accuracy: 0.6019
# Epoch 281/500
# 13/13 [==============================] - 5s 382ms/step - loss: 0.9411 - accuracy: 0.6124 - val_loss: 0.6897 - val_accuracy: 0.7130
# Epoch 282/500
# 13/13 [==============================] - 5s 373ms/step - loss: 0.9541 - accuracy: 0.6255 - val_loss: 0.8784 - val_accuracy: 0.6019
# Epoch 283/500
# 13/13 [==============================] - 5s 369ms/step - loss: 0.9348 - accuracy: 0.6787 - val_loss: 1.2861 - val_accuracy: 0.5185
# Epoch 284/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.1819 - accuracy: 0.6420 - val_loss: 2.0074 - val_accuracy: 0.4352
# Epoch 285/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.4407 - accuracy: 0.6184 - val_loss: 2.2428 - val_accuracy: 0.3981
# Epoch 286/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.6069 - accuracy: 0.6075 - val_loss: 3.1349 - val_accuracy: 0.3981
# Epoch 287/500
# 13/13 [==============================] - 5s 362ms/step - loss: 2.3556 - accuracy: 0.5220 - val_loss: 1.0848 - val_accuracy: 0.5463
# Epoch 288/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.9136 - accuracy: 0.6206 - val_loss: 0.7029 - val_accuracy: 0.6944
# Epoch 289/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.7735 - accuracy: 0.7126 - val_loss: 0.9704 - val_accuracy: 0.6111
# Epoch 290/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.0616 - accuracy: 0.6593 - val_loss: 2.0290 - val_accuracy: 0.4444
# Epoch 291/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.1160 - accuracy: 0.6252 - val_loss: 0.5967 - val_accuracy: 0.7222
# Epoch 292/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1031 - accuracy: 0.6613 - val_loss: 1.5160 - val_accuracy: 0.4907
# Epoch 293/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.6343 - accuracy: 0.6164 - val_loss: 1.9488 - val_accuracy: 0.4537
# Epoch 294/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.1139 - accuracy: 0.6565 - val_loss: 1.2018 - val_accuracy: 0.5463
# Epoch 295/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.2855 - accuracy: 0.5791 - val_loss: 0.7796 - val_accuracy: 0.6574
# Epoch 296/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.2094 - accuracy: 0.6446 - val_loss: 0.5965 - val_accuracy: 0.7593
# Epoch 297/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.0528 - accuracy: 0.6277 - val_loss: 0.5508 - val_accuracy: 0.7593
# Epoch 298/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1535 - accuracy: 0.6238 - val_loss: 1.1539 - val_accuracy: 0.5648
# Epoch 299/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.1274 - accuracy: 0.6516 - val_loss: 1.3800 - val_accuracy: 0.5185
# Epoch 300/500
# 13/13 [==============================] - 5s 367ms/step - loss: 1.1322 - accuracy: 0.6439 - val_loss: 1.8975 - val_accuracy: 0.4722
# Epoch 301/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.5180 - accuracy: 0.5653 - val_loss: 2.3637 - val_accuracy: 0.4259
# Epoch 302/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.2085 - accuracy: 0.6316 - val_loss: 0.6048 - val_accuracy: 0.7407
# Epoch 303/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.9401 - accuracy: 0.6299 - val_loss: 0.6927 - val_accuracy: 0.7130
# Epoch 304/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.1316 - accuracy: 0.6196 - val_loss: 1.4483 - val_accuracy: 0.5000
# Epoch 305/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.9836 - accuracy: 0.6541 - val_loss: 0.9863 - val_accuracy: 0.5833
# Epoch 306/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9237 - accuracy: 0.6581 - val_loss: 0.5263 - val_accuracy: 0.7870
# Epoch 307/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8933 - accuracy: 0.6790 - val_loss: 1.2327 - val_accuracy: 0.5370
# Epoch 308/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0267 - accuracy: 0.6895 - val_loss: 1.7150 - val_accuracy: 0.4722
# Epoch 309/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.1068 - accuracy: 0.6478 - val_loss: 0.5523 - val_accuracy: 0.7593
# Epoch 310/500
# 13/13 [==============================] - 5s 360ms/step - loss: 0.9136 - accuracy: 0.6559 - val_loss: 0.5650 - val_accuracy: 0.7778
# Epoch 311/500
# 13/13 [==============================] - 5s 358ms/step - loss: 0.9734 - accuracy: 0.6722 - val_loss: 0.8280 - val_accuracy: 0.6296
# Epoch 312/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0891 - accuracy: 0.6250 - val_loss: 1.5546 - val_accuracy: 0.4722
# Epoch 313/500
# 13/13 [==============================] - 5s 358ms/step - loss: 1.4528 - accuracy: 0.5801 - val_loss: 0.5501 - val_accuracy: 0.7500
# Epoch 314/500
# 13/13 [==============================] - 5s 357ms/step - loss: 0.9422 - accuracy: 0.7149 - val_loss: 0.7753 - val_accuracy: 0.6944
# Epoch 315/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0656 - accuracy: 0.6437 - val_loss: 0.5049 - val_accuracy: 0.7870
# Epoch 316/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0225 - accuracy: 0.6710 - val_loss: 0.9923 - val_accuracy: 0.5556
# Epoch 317/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.1172 - accuracy: 0.6321 - val_loss: 1.3441 - val_accuracy: 0.4815
# Epoch 318/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1727 - accuracy: 0.6328 - val_loss: 1.1718 - val_accuracy: 0.5185
# Epoch 319/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0832 - accuracy: 0.6099 - val_loss: 0.7193 - val_accuracy: 0.6481
# Epoch 320/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9499 - accuracy: 0.6459 - val_loss: 0.6393 - val_accuracy: 0.6944
# Epoch 321/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.2072 - accuracy: 0.6114 - val_loss: 0.5102 - val_accuracy: 0.8241
# Epoch 322/500
# 13/13 [==============================] - 5s 358ms/step - loss: 1.4204 - accuracy: 0.6378 - val_loss: 0.5383 - val_accuracy: 0.7593
# Epoch 323/500
# 13/13 [==============================] - 5s 368ms/step - loss: 1.0649 - accuracy: 0.6786 - val_loss: 0.9599 - val_accuracy: 0.6574
# Epoch 324/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.3311 - accuracy: 0.5802 - val_loss: 1.3998 - val_accuracy: 0.4907
# Epoch 325/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.1460 - accuracy: 0.6591 - val_loss: 0.5786 - val_accuracy: 0.7130
# Epoch 326/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.3679 - accuracy: 0.6049 - val_loss: 0.6838 - val_accuracy: 0.7037
# Epoch 327/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.1030 - accuracy: 0.6646 - val_loss: 0.8415 - val_accuracy: 0.6389
# Epoch 328/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.0041 - accuracy: 0.6625 - val_loss: 1.1597 - val_accuracy: 0.5463
# Epoch 329/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.2357 - accuracy: 0.6278 - val_loss: 1.1513 - val_accuracy: 0.5463
# Epoch 330/500
# 13/13 [==============================] - 5s 381ms/step - loss: 1.3660 - accuracy: 0.6083 - val_loss: 0.5409 - val_accuracy: 0.7500
# Epoch 331/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.0563 - accuracy: 0.6606 - val_loss: 0.8165 - val_accuracy: 0.6204
# Epoch 332/500
# ...
# Epoch 391/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9881 - accuracy: 0.6321 - val_loss: 0.7652 - val_accuracy: 0.6204
# Epoch 392/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.8919 - accuracy: 0.6948 - val_loss: 0.6094 - val_accuracy: 0.7037
# Epoch 393/500
# 13/13 [==============================] - 5s 383ms/step - loss: 1.0305 - accuracy: 0.6807 - val_loss: 0.8503 - val_accuracy: 0.6481
# Epoch 394/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.5330 - accuracy: 0.6157 - val_loss: 0.4709 - val_accuracy: 0.8241
# Epoch 395/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.8807 - accuracy: 0.6612 - val_loss: 0.4646 - val_accuracy: 0.7963
# Epoch 396/500
# 13/13 [==============================] - 5s 365ms/step - loss: 0.9933 - accuracy: 0.6873 - val_loss: 0.5296 - val_accuracy: 0.7685
# Epoch 397/500
# 13/13 [==============================] - 5s 368ms/step - loss: 1.1340 - accuracy: 0.6090 - val_loss: 0.5009 - val_accuracy: 0.8056
# Epoch 398/500
# 13/13 [==============================] - 5s 367ms/step - loss: 0.9590 - accuracy: 0.6738 - val_loss: 2.0488 - val_accuracy: 0.4167
# Epoch 399/500
# 13/13 [==============================] - 5s 368ms/step - loss: 1.3951 - accuracy: 0.6271 - val_loss: 0.7967 - val_accuracy: 0.6111
# Epoch 400/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.1546 - accuracy: 0.6516 - val_loss: 0.4815 - val_accuracy: 0.7870
# Epoch 401/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.0390 - accuracy: 0.6776 - val_loss: 0.6464 - val_accuracy: 0.7222
# Epoch 402/500
# 13/13 [==============================] - 5s 361ms/step - loss: 1.2410 - accuracy: 0.6631 - val_loss: 0.6256 - val_accuracy: 0.7222
# Epoch 403/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1638 - accuracy: 0.6539 - val_loss: 0.4707 - val_accuracy: 0.8333
# Epoch 404/500
# 13/13 [==============================] - 5s 363ms/step - loss: 0.9473 - accuracy: 0.6877 - val_loss: 0.4866 - val_accuracy: 0.7778
# Epoch 405/500
# 13/13 [==============================] - 5s 364ms/step - loss: 0.9347 - accuracy: 0.6542 - val_loss: 0.7773 - val_accuracy: 0.6481
# Epoch 406/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.2527 - accuracy: 0.6151 - val_loss: 2.9206 - val_accuracy: 0.3981
# Epoch 407/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.9447 - accuracy: 0.5349 - val_loss: 1.2916 - val_accuracy: 0.5000
# Epoch 408/500
# 13/13 [==============================] - 5s 361ms/step - loss: 0.9992 - accuracy: 0.6449 - val_loss: 0.4857 - val_accuracy: 0.7963
# Epoch 409/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1967 - accuracy: 0.6974 - val_loss: 0.4764 - val_accuracy: 0.8241
# Epoch 410/500
# 13/13 [==============================] - 5s 364ms/step - loss: 0.8421 - accuracy: 0.6876 - val_loss: 0.4819 - val_accuracy: 0.8148
# Epoch 411/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.9596 - accuracy: 0.6847 - val_loss: 0.6482 - val_accuracy: 0.7037
# Epoch 412/500
# 13/13 [==============================] - 5s 381ms/step - loss: 1.0142 - accuracy: 0.6889 - val_loss: 1.3100 - val_accuracy: 0.5185
# Epoch 413/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.0807 - accuracy: 0.6345 - val_loss: 1.4075 - val_accuracy: 0.5370
# Epoch 414/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0057 - accuracy: 0.6504 - val_loss: 0.8608 - val_accuracy: 0.6111
# Epoch 415/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.0448 - accuracy: 0.6502 - val_loss: 0.4914 - val_accuracy: 0.8148
# Epoch 416/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.2198 - accuracy: 0.6668 - val_loss: 0.4943 - val_accuracy: 0.8241
# Epoch 417/500
# 13/13 [==============================] - 5s 359ms/step - loss: 1.3235 - accuracy: 0.6103 - val_loss: 0.8795 - val_accuracy: 0.6574
# Epoch 418/500
# 13/13 [==============================] - 5s 360ms/step - loss: 1.5627 - accuracy: 0.6515 - val_loss: 0.4823 - val_accuracy: 0.8148
# Epoch 419/500
# 13/13 [==============================] - 5s 359ms/step - loss: 0.9522 - accuracy: 0.6561 - val_loss: 0.6078 - val_accuracy: 0.7315
# Epoch 420/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1902 - accuracy: 0.6127 - val_loss: 0.6331 - val_accuracy: 0.7315
# Epoch 421/500
# 13/13 [==============================] - 6s 429ms/step - loss: 1.1744 - accuracy: 0.7079 - val_loss: 1.0856 - val_accuracy: 0.5370
# Epoch 422/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.4247 - accuracy: 0.6322 - val_loss: 1.7656 - val_accuracy: 0.4722
# Epoch 423/500
# 13/13 [==============================] - 5s 363ms/step - loss: 1.6462 - accuracy: 0.5511 - val_loss: 0.4939 - val_accuracy: 0.8056
# Epoch 424/500
# 13/13 [==============================] - 5s 362ms/step - loss: 1.1370 - accuracy: 0.6232 - val_loss: 0.9175 - val_accuracy: 0.6111
# Epoch 425/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.0699 - accuracy: 0.6229 - val_loss: 0.5412 - val_accuracy: 0.8056
# Epoch 426/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.1488 - accuracy: 0.6685 - val_loss: 0.8528 - val_accuracy: 0.6852
# Epoch 427/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0530 - accuracy: 0.6462 - val_loss: 0.6582 - val_accuracy: 0.7037
# Epoch 428/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.4306 - accuracy: 0.6119 - val_loss: 0.6923 - val_accuracy: 0.7037
# Epoch 429/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0994 - accuracy: 0.6577 - val_loss: 0.5167 - val_accuracy: 0.8056
# Epoch 430/500
# 13/13 [==============================] - 5s 367ms/step - loss: 0.9698 - accuracy: 0.6594 - val_loss: 1.2898 - val_accuracy: 0.6019
# Epoch 431/500
# 13/13 [==============================] - 5s 367ms/step - loss: 1.6919 - accuracy: 0.5895 - val_loss: 0.6092 - val_accuracy: 0.7500
# Epoch 432/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.2695 - accuracy: 0.6282 - val_loss: 1.1594 - val_accuracy: 0.6204
# Epoch 433/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.4224 - accuracy: 0.6346 - val_loss: 0.5668 - val_accuracy: 0.7500
# Epoch 434/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0219 - accuracy: 0.6779 - val_loss: 1.2636 - val_accuracy: 0.5463
# Epoch 435/500
# 13/13 [==============================] - 5s 362ms/step - loss: 0.8855 - accuracy: 0.6741 - val_loss: 0.5284 - val_accuracy: 0.7685
# Epoch 436/500
# 13/13 [==============================] - 5s 366ms/step - loss: 0.9802 - accuracy: 0.6907 - val_loss: 0.6660 - val_accuracy: 0.7500
# Epoch 437/500
# 13/13 [==============================] - 5s 366ms/step - loss: 1.1552 - accuracy: 0.6624 - val_loss: 0.5665 - val_accuracy: 0.7500
# Epoch 438/500
# 13/13 [==============================] - 5s 373ms/step - loss: 0.8774 - accuracy: 0.7084 - val_loss: 1.0691 - val_accuracy: 0.5741
# Epoch 439/500
# 13/13 [==============================] - 5s 370ms/step - loss: 1.3487 - accuracy: 0.5679 - val_loss: 1.0256 - val_accuracy: 0.5648
# Epoch 440/500
# 13/13 [==============================] - 5s 374ms/step - loss: 1.1372 - accuracy: 0.6455 - val_loss: 0.5266 - val_accuracy: 0.7685
# Epoch 441/500
# 13/13 [==============================] - 5s 367ms/step - loss: 0.9033 - accuracy: 0.7023 - val_loss: 0.9487 - val_accuracy: 0.5833
# Epoch 442/500
# 13/13 [==============================] - 5s 366ms/step - loss: 0.8680 - accuracy: 0.7108 - val_loss: 0.7863 - val_accuracy: 0.6574
# Epoch 443/500
# 13/13 [==============================] - 5s 367ms/step - loss: 0.9062 - accuracy: 0.6698 - val_loss: 0.5119 - val_accuracy: 0.8056
# Epoch 444/500
# 13/13 [==============================] - 5s 386ms/step - loss: 0.9608 - accuracy: 0.6445 - val_loss: 0.7570 - val_accuracy: 0.6852
# Epoch 445/500
# 13/13 [==============================] - 5s 367ms/step - loss: 1.0397 - accuracy: 0.6384 - val_loss: 0.5234 - val_accuracy: 0.7870
# Epoch 446/500
# 13/13 [==============================] - 5s 372ms/step - loss: 1.4131 - accuracy: 0.6186 - val_loss: 0.9266 - val_accuracy: 0.6574
# Epoch 447/500
# 13/13 [==============================] - 5s 374ms/step - loss: 1.2216 - accuracy: 0.6504 - val_loss: 1.3422 - val_accuracy: 0.6019
# Epoch 448/500
# 13/13 [==============================] - 5s 372ms/step - loss: 1.4167 - accuracy: 0.6165 - val_loss: 1.2927 - val_accuracy: 0.6019
# Epoch 449/500
# 13/13 [==============================] - 5s 370ms/step - loss: 1.4143 - accuracy: 0.6689 - val_loss: 1.0026 - val_accuracy: 0.6574
# Epoch 450/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.3608 - accuracy: 0.6251 - val_loss: 0.6054 - val_accuracy: 0.7500
# Epoch 451/500
# 13/13 [==============================] - 5s 367ms/step - loss: 1.2791 - accuracy: 0.6564 - val_loss: 0.5297 - val_accuracy: 0.7500
# Epoch 452/500
# 13/13 [==============================] - 5s 389ms/step - loss: 0.9136 - accuracy: 0.6647 - val_loss: 0.5590 - val_accuracy: 0.7593
# Epoch 453/500
# 13/13 [==============================] - 5s 367ms/step - loss: 1.1091 - accuracy: 0.6499 - val_loss: 0.6096 - val_accuracy: 0.7500
# Epoch 454/500
# 13/13 [==============================] - 5s 367ms/step - loss: 1.1122 - accuracy: 0.6500 - val_loss: 0.5383 - val_accuracy: 0.7500
# Epoch 455/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.1254 - accuracy: 0.6547 - val_loss: 0.5328 - val_accuracy: 0.7593
# Epoch 456/500
# 13/13 [==============================] - 5s 368ms/step - loss: 1.1097 - accuracy: 0.6859 - val_loss: 0.5327 - val_accuracy: 0.7685
# Epoch 457/500
# 13/13 [==============================] - 5s 368ms/step - loss: 1.2669 - accuracy: 0.6338 - val_loss: 0.5204 - val_accuracy: 0.8333
# Epoch 458/500
# 13/13 [==============================] - 5s 365ms/step - loss: 0.9959 - accuracy: 0.6391 - val_loss: 0.5982 - val_accuracy: 0.7130
# Epoch 459/500
# 13/13 [==============================] - 5s 366ms/step - loss: 0.8819 - accuracy: 0.7242 - val_loss: 0.5053 - val_accuracy: 0.8426
# Epoch 460/500
# 13/13 [==============================] - 5s 392ms/step - loss: 1.1074 - accuracy: 0.6284 - val_loss: 0.5206 - val_accuracy: 0.8148
# Epoch 461/500
# 13/13 [==============================] - 5s 375ms/step - loss: 0.9301 - accuracy: 0.7045 - val_loss: 0.6780 - val_accuracy: 0.7037
# Epoch 462/500
# 13/13 [==============================] - 5s 377ms/step - loss: 0.9927 - accuracy: 0.6733 - val_loss: 1.0757 - val_accuracy: 0.5648
# Epoch 463/500
# 13/13 [==============================] - 5s 373ms/step - loss: 0.9301 - accuracy: 0.6667 - val_loss: 0.6387 - val_accuracy: 0.7500
# Epoch 464/500
# 13/13 [==============================] - 5s 376ms/step - loss: 1.0841 - accuracy: 0.6515 - val_loss: 0.5967 - val_accuracy: 0.7407
# Epoch 465/500
# 13/13 [==============================] - 5s 374ms/step - loss: 1.1246 - accuracy: 0.6271 - val_loss: 0.6462 - val_accuracy: 0.7037
# Epoch 466/500
# 13/13 [==============================] - 5s 390ms/step - loss: 0.9011 - accuracy: 0.6394 - val_loss: 0.8061 - val_accuracy: 0.6389
# Epoch 467/500
# 13/13 [==============================] - 5s 372ms/step - loss: 0.8481 - accuracy: 0.6876 - val_loss: 0.8335 - val_accuracy: 0.6204
# Epoch 468/500
# 13/13 [==============================] - 5s 371ms/step - loss: 1.0223 - accuracy: 0.6239 - val_loss: 0.6562 - val_accuracy: 0.6944
# Epoch 469/500
# 13/13 [==============================] - 5s 371ms/step - loss: 0.8527 - accuracy: 0.7170 - val_loss: 0.7503 - val_accuracy: 0.6852
# Epoch 470/500
# 13/13 [==============================] - 5s 371ms/step - loss: 0.9412 - accuracy: 0.6774 - val_loss: 0.4919 - val_accuracy: 0.8148
# Epoch 471/500
# 13/13 [==============================] - 5s 373ms/step - loss: 1.0810 - accuracy: 0.6482 - val_loss: 0.5618 - val_accuracy: 0.7222
# Epoch 472/500
# 13/13 [==============================] - 5s 375ms/step - loss: 1.0671 - accuracy: 0.6341 - val_loss: 0.6286 - val_accuracy: 0.6944
# Epoch 473/500
# 13/13 [==============================] - 5s 367ms/step - loss: 0.9036 - accuracy: 0.6849 - val_loss: 0.6525 - val_accuracy: 0.6759
# Epoch 474/500
# 13/13 [==============================] - 5s 370ms/step - loss: 0.9347 - accuracy: 0.6875 - val_loss: 1.4187 - val_accuracy: 0.4815
# Epoch 475/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.2409 - accuracy: 0.5862 - val_loss: 0.4810 - val_accuracy: 0.8241
# Epoch 476/500
# 13/13 [==============================] - 5s 371ms/step - loss: 1.1948 - accuracy: 0.6382 - val_loss: 0.4825 - val_accuracy: 0.8148
# Epoch 477/500
# 13/13 [==============================] - 5s 371ms/step - loss: 0.9190 - accuracy: 0.6826 - val_loss: 0.5110 - val_accuracy: 0.7685
# Epoch 478/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.0853 - accuracy: 0.6460 - val_loss: 0.4947 - val_accuracy: 0.8333
# Epoch 479/500
# 13/13 [==============================] - 5s 376ms/step - loss: 1.2832 - accuracy: 0.6442 - val_loss: 0.6419 - val_accuracy: 0.7407
# Epoch 480/500
# 13/13 [==============================] - 5s 376ms/step - loss: 0.9776 - accuracy: 0.6842 - val_loss: 0.6176 - val_accuracy: 0.6944
# Epoch 481/500
# 13/13 [==============================] - 5s 370ms/step - loss: 0.9528 - accuracy: 0.6579 - val_loss: 0.7437 - val_accuracy: 0.6574
# Epoch 482/500
# 13/13 [==============================] - 5s 366ms/step - loss: 0.9978 - accuracy: 0.6827 - val_loss: 1.3491 - val_accuracy: 0.6019
# Epoch 483/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.2514 - accuracy: 0.6507 - val_loss: 0.8777 - val_accuracy: 0.6296
# Epoch 484/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.0992 - accuracy: 0.6393 - val_loss: 0.6440 - val_accuracy: 0.6759
# Epoch 485/500
# 13/13 [==============================] - 5s 368ms/step - loss: 1.0225 - accuracy: 0.6740 - val_loss: 0.5564 - val_accuracy: 0.7870
# Epoch 486/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0275 - accuracy: 0.6731 - val_loss: 0.4744 - val_accuracy: 0.8148
# Epoch 487/500
# 13/13 [==============================] - 5s 369ms/step - loss: 0.9211 - accuracy: 0.6679 - val_loss: 0.6039 - val_accuracy: 0.7685
# Epoch 488/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.0966 - accuracy: 0.6801 - val_loss: 0.4886 - val_accuracy: 0.8426
# Epoch 489/500
# 13/13 [==============================] - 5s 365ms/step - loss: 0.9235 - accuracy: 0.6765 - val_loss: 0.4985 - val_accuracy: 0.7685
# Epoch 490/500
# 13/13 [==============================] - 5s 375ms/step - loss: 0.9940 - accuracy: 0.6351 - val_loss: 0.5596 - val_accuracy: 0.8148
# Epoch 491/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.1504 - accuracy: 0.6410 - val_loss: 0.5381 - val_accuracy: 0.7500
# Epoch 492/500
# 13/13 [==============================] - 5s 383ms/step - loss: 1.0952 - accuracy: 0.6333 - val_loss: 0.5306 - val_accuracy: 0.8241
# Epoch 493/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.4609 - accuracy: 0.6176 - val_loss: 0.4890 - val_accuracy: 0.8241
# Epoch 494/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.1263 - accuracy: 0.6429 - val_loss: 0.5816 - val_accuracy: 0.7222
# Epoch 495/500
# 13/13 [==============================] - 5s 370ms/step - loss: 1.2167 - accuracy: 0.6474 - val_loss: 0.8565 - val_accuracy: 0.6296
# Epoch 496/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.0257 - accuracy: 0.6346 - val_loss: 1.0805 - val_accuracy: 0.5556
# Epoch 497/500
# 13/13 [==============================] - 5s 369ms/step - loss: 1.0159 - accuracy: 0.6783 - val_loss: 0.5192 - val_accuracy: 0.8148
# Epoch 498/500
# 13/13 [==============================] - 5s 365ms/step - loss: 1.8168 - accuracy: 0.5964 - val_loss: 1.5720 - val_accuracy: 0.4907
# Epoch 499/500
# 13/13 [==============================] - 5s 363ms/step - loss: 2.7382 - accuracy: 0.5111 - val_loss: 2.5549 - val_accuracy: 0.4259
# Epoch 500/500
# 13/13 [==============================] - 5s 364ms/step - loss: 1.5004 - accuracy: 0.5822 - val_loss: 0.5806 - val_accuracy: 0.7222

# %%
# Save Model and Weights
model.save('500epochs_malaria_2_resnet50.h5')
model.save_weights('500epochs_malaria_2_resnet50_weights.hdf5')

# %%
import tensorflow as tf
from tensorflow import keras
tf.keras.models.save_model(model, '/content/drive/MyDrive/cell_images_3/resnet50 model')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/cell_images_3/resnet50 model/assets

# %%
# Load saved model
model = load_model('/content/drive/MyDrive/cell_images_3/resnet50 model')

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% parasite')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% uninfected')
  plt.style.reload_library
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
def plot_confusion_matrix(normalize):
  classes = ['parasite','uninfected']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.65      0.74        65
#            1       0.61      0.84      0.71        43
#
#     accuracy                           0.72       108
#    macro avg       0.73      0.74      0.72       108
# weighted avg       0.76      0.72      0.72       108

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('500epochs_resnet50_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('500epochs_resnet50_loss.png')
plt.show()

# %%
#ACCURACY
from sklearn.metrics import accuracy_score
print('Accuracy score:' , accuracy_score(y_test_bin, y_pred_bin))
# Out:
# Accuracy score: 0.7222222222222222
