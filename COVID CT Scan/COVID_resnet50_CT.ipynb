# %% [markdown]
# <a href="https://colab.research.google.com/github/nah16d/Thesis/blob/main/COVID%20CT%20Scan/COVID_resnet50_CT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Jan 11 18:23:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
#define size to which images are to be resized
IMAGE_SIZE = [224, 224] # feel free to change depending on dataset

# training config:
epochs = 500
batch_size = 32

#define paths
covid_path = '/content/drive/MyDrive/COVID/Datasets/CT/CT_COVID'
noncovid_path = '/content/drive/MyDrive/COVID/Datasets/CT/CT_NonCOVID'

# Use glob to grab images from path .jpg or jpeg
covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Visualize file variable contents
print("First 5 Covid Files: ",covid_files[0:5])
print("Total Count: ",len(covid_files))
print("First 5 NonCovid Files: ",noncovid_files[0:5])
print("Total Count: ",len(noncovid_files))
# Out:
# First 5 Covid Files:  ['/content/drive/MyDrive/COVID/Datasets/CT/CT_COVID/2020.03.26.20041426-p11-127.png', '/content/drive/MyDrive/COVID/Datasets/CT/CT_COVID/2020.03.07.20031393-p7-50_1.png', '/content/drive/MyDrive/COVID/Datasets/CT/CT_COVID/2020.02.11.20021493-p16-109_1.png', '/content/drive/MyDrive/COVID/Datasets/CT/CT_COVID/2020.02.25.20021568-p23-108_13.png', '/content/drive/MyDrive/COVID/Datasets/CT/CT_COVID/Ni2020_Article_CombinationOfWesternMedicineAn-p3-10_1.png']
# Total Count:  349
# First 5 NonCovid Files:  ['/content/drive/MyDrive/COVID/Datasets/CT/CT_NonCOVID/4_1.jpg', '/content/drive/MyDrive/COVID/Datasets/CT/CT_NonCOVID/577.png', '/content/drive/MyDrive/COVID/Datasets/CT/CT_NonCOVID/227.png', '/content/drive/MyDrive/COVID/Datasets/CT/CT_NonCOVID/49_0.jpg', '/content/drive/MyDrive/COVID/Datasets/CT/CT_NonCOVID/1030.png']
# Total Count:  407

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per kera
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') # append class label
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
   # look at a random image for fun
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(covid_images, 'Positive COVID-19 CT Scan')
plot_images(noncovid_images, 'Negative COVID-19 CT Scan')

# %%
# Convert to array and Normalize to interval of [0,1]
covid_images = np.array(covid_images) / 255
noncovid_images = np.array(noncovid_images) / 255

# %%
# split into training and testing
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)


X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
plot_images(covid_x_train, 'X_train')
plot_images(covid_x_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing COVID and NonCOVID for X_train and X_test

# %%
resnet = ResNet50(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = resnet.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=resnet.input, outputs=outputs)

for layer in resnet.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
# Visualize Model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100352)       0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100352)       0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            200706      dropout[0][0]
# ==================================================================================================
# Total params: 23,788,418
# Trainable params: 200,706
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %%
history = model.fit(train_aug.flow(X_train, y_train, batch_size=batch_size),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / batch_size,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=epochs)
# Out:
# Epoch 1/500
# 18/18 [==============================] - 17s 424ms/step - loss: 2.4275 - accuracy: 0.5137 - val_loss: 0.6617 - val_accuracy: 0.6316
# Epoch 2/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.1158 - accuracy: 0.5145 - val_loss: 0.7674 - val_accuracy: 0.5658
# Epoch 3/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.0351 - accuracy: 0.5434 - val_loss: 0.7260 - val_accuracy: 0.5855
# Epoch 4/500
# 18/18 [==============================] - 7s 356ms/step - loss: 0.9760 - accuracy: 0.5636 - val_loss: 1.0714 - val_accuracy: 0.4605
# Epoch 5/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.3033 - accuracy: 0.5219 - val_loss: 0.7771 - val_accuracy: 0.5789
# Epoch 6/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.4804 - accuracy: 0.4983 - val_loss: 0.6163 - val_accuracy: 0.7039
# Epoch 7/500
# 18/18 [==============================] - 7s 357ms/step - loss: 0.9252 - accuracy: 0.6356 - val_loss: 0.7277 - val_accuracy: 0.6513
# Epoch 8/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.0766 - accuracy: 0.5760 - val_loss: 0.4415 - val_accuracy: 0.7829
# Epoch 9/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.8896 - accuracy: 0.6060 - val_loss: 0.5162 - val_accuracy: 0.7566
# Epoch 10/500
# 18/18 [==============================] - 7s 356ms/step - loss: 0.9844 - accuracy: 0.5852 - val_loss: 0.4372 - val_accuracy: 0.7697
# Epoch 11/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.0454 - accuracy: 0.5437 - val_loss: 0.4493 - val_accuracy: 0.7632
# Epoch 12/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.4625 - accuracy: 0.5567 - val_loss: 0.6394 - val_accuracy: 0.6974
# Epoch 13/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0851 - accuracy: 0.6045 - val_loss: 0.4511 - val_accuracy: 0.7697
# Epoch 14/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.9524 - accuracy: 0.5854 - val_loss: 0.5303 - val_accuracy: 0.7500
# Epoch 15/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.8660 - accuracy: 0.6322 - val_loss: 0.4446 - val_accuracy: 0.7829
# Epoch 16/500
# 18/18 [==============================] - 7s 357ms/step - loss: 0.9417 - accuracy: 0.6153 - val_loss: 0.5981 - val_accuracy: 0.7368
# Epoch 17/500
# 18/18 [==============================] - 7s 357ms/step - loss: 0.9365 - accuracy: 0.6166 - val_loss: 0.6645 - val_accuracy: 0.6513
# Epoch 18/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0163 - accuracy: 0.5959 - val_loss: 0.4090 - val_accuracy: 0.8026
# Epoch 19/500
# 18/18 [==============================] - 7s 367ms/step - loss: 0.9137 - accuracy: 0.6134 - val_loss: 0.4168 - val_accuracy: 0.8092
# Epoch 20/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.8214 - accuracy: 0.6419 - val_loss: 0.7794 - val_accuracy: 0.6447
# Epoch 21/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.1843 - accuracy: 0.5463 - val_loss: 0.7902 - val_accuracy: 0.6974
# Epoch 22/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.0555 - accuracy: 0.6513 - val_loss: 0.4109 - val_accuracy: 0.8092
# Epoch 23/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.8005 - accuracy: 0.6687 - val_loss: 0.4541 - val_accuracy: 0.7895
# Epoch 24/500
# 18/18 [==============================] - 7s 363ms/step - loss: 0.8906 - accuracy: 0.6248 - val_loss: 0.3977 - val_accuracy: 0.7961
# Epoch 25/500
# 18/18 [==============================] - 7s 364ms/step - loss: 1.1835 - accuracy: 0.5975 - val_loss: 1.0168 - val_accuracy: 0.6842
# Epoch 26/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.6231 - accuracy: 0.5776 - val_loss: 0.6973 - val_accuracy: 0.7039
# Epoch 27/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1428 - accuracy: 0.6054 - val_loss: 0.9678 - val_accuracy: 0.6316
# Epoch 28/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.1636 - accuracy: 0.5946 - val_loss: 0.4207 - val_accuracy: 0.8158
# Epoch 29/500
# 18/18 [==============================] - 7s 361ms/step - loss: 0.8646 - accuracy: 0.6479 - val_loss: 0.5021 - val_accuracy: 0.7500
# Epoch 30/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0136 - accuracy: 0.5869 - val_loss: 0.5784 - val_accuracy: 0.7171
# Epoch 31/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.8987 - accuracy: 0.6522 - val_loss: 0.8571 - val_accuracy: 0.6776
# Epoch 32/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.2737 - accuracy: 0.6372 - val_loss: 0.4566 - val_accuracy: 0.7763
# Epoch 33/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.9367 - accuracy: 0.6542 - val_loss: 0.5950 - val_accuracy: 0.7434
# Epoch 34/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9016 - accuracy: 0.6483 - val_loss: 0.8747 - val_accuracy: 0.6382
# Epoch 35/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.2117 - accuracy: 0.6261 - val_loss: 0.7469 - val_accuracy: 0.7039
# Epoch 36/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.0768 - accuracy: 0.6206 - val_loss: 0.5227 - val_accuracy: 0.7697
# Epoch 37/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.1056 - accuracy: 0.6000 - val_loss: 0.3919 - val_accuracy: 0.8289
# Epoch 38/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.0697 - accuracy: 0.6406 - val_loss: 1.6579 - val_accuracy: 0.5066
# Epoch 39/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.2471 - accuracy: 0.6050 - val_loss: 0.4396 - val_accuracy: 0.7961
# Epoch 40/500
# 18/18 [==============================] - 7s 362ms/step - loss: 0.7969 - accuracy: 0.6481 - val_loss: 0.5853 - val_accuracy: 0.7039
# Epoch 41/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.9422 - accuracy: 0.6495 - val_loss: 0.6847 - val_accuracy: 0.7237
# Epoch 42/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.0059 - accuracy: 0.6038 - val_loss: 0.6660 - val_accuracy: 0.7697
# Epoch 43/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.0807 - accuracy: 0.6345 - val_loss: 1.3295 - val_accuracy: 0.6382
# Epoch 44/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.2154 - accuracy: 0.6392 - val_loss: 1.4501 - val_accuracy: 0.6382
# Epoch 45/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.6757 - accuracy: 0.5646 - val_loss: 1.4033 - val_accuracy: 0.6579
# Epoch 46/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.2574 - accuracy: 0.6381 - val_loss: 0.8648 - val_accuracy: 0.7368
# Epoch 47/500
# 18/18 [==============================] - 7s 364ms/step - loss: 1.1580 - accuracy: 0.6445 - val_loss: 0.5429 - val_accuracy: 0.7171
# Epoch 48/500
# 18/18 [==============================] - 7s 365ms/step - loss: 1.0177 - accuracy: 0.6254 - val_loss: 0.6549 - val_accuracy: 0.7697
# Epoch 49/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.0920 - accuracy: 0.6468 - val_loss: 1.5453 - val_accuracy: 0.5395
# Epoch 50/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.6887 - accuracy: 0.5775 - val_loss: 1.1150 - val_accuracy: 0.6053
# Epoch 51/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1047 - accuracy: 0.6482 - val_loss: 0.7654 - val_accuracy: 0.6579
# Epoch 52/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1740 - accuracy: 0.6072 - val_loss: 0.4253 - val_accuracy: 0.8158
# Epoch 53/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0357 - accuracy: 0.6087 - val_loss: 0.4218 - val_accuracy: 0.8092
# Epoch 54/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.0904 - accuracy: 0.6236 - val_loss: 0.5101 - val_accuracy: 0.7961
# Epoch 55/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1793 - accuracy: 0.5842 - val_loss: 0.5679 - val_accuracy: 0.6974
# Epoch 56/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.1099 - accuracy: 0.6427 - val_loss: 0.8134 - val_accuracy: 0.6908
# Epoch 57/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9466 - accuracy: 0.6752 - val_loss: 0.5595 - val_accuracy: 0.7039
# Epoch 58/500
# 18/18 [==============================] - 7s 362ms/step - loss: 0.9398 - accuracy: 0.6372 - val_loss: 0.8536 - val_accuracy: 0.6974
# Epoch 59/500
# 18/18 [==============================] - 7s 364ms/step - loss: 1.0496 - accuracy: 0.6139 - val_loss: 0.3993 - val_accuracy: 0.8158
# Epoch 60/500
# 18/18 [==============================] - 7s 363ms/step - loss: 0.9012 - accuracy: 0.6296 - val_loss: 0.4045 - val_accuracy: 0.8092
# Epoch 61/500
# 18/18 [==============================] - 7s 361ms/step - loss: 0.9665 - accuracy: 0.6483 - val_loss: 0.4193 - val_accuracy: 0.7829
# Epoch 62/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.9008 - accuracy: 0.6621 - val_loss: 0.7525 - val_accuracy: 0.6974
# Epoch 63/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.2228 - accuracy: 0.6421 - val_loss: 0.4791 - val_accuracy: 0.7895
# Epoch 64/500
# 18/18 [==============================] - 7s 366ms/step - loss: 0.9993 - accuracy: 0.6362 - val_loss: 0.7725 - val_accuracy: 0.6974
# Epoch 65/500
# 18/18 [==============================] - 7s 365ms/step - loss: 1.0400 - accuracy: 0.6225 - val_loss: 0.6403 - val_accuracy: 0.7105
# Epoch 66/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.1636 - accuracy: 0.6158 - val_loss: 0.5396 - val_accuracy: 0.7697
# Epoch 67/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.3847 - accuracy: 0.5867 - val_loss: 0.4865 - val_accuracy: 0.7829
# Epoch 68/500
# 18/18 [==============================] - 7s 362ms/step - loss: 0.8153 - accuracy: 0.6509 - val_loss: 0.4727 - val_accuracy: 0.7829
# Epoch 69/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.9579 - accuracy: 0.6493 - val_loss: 0.5408 - val_accuracy: 0.7500
# Epoch 70/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.8563 - accuracy: 0.6778 - val_loss: 1.8426 - val_accuracy: 0.4934
# Epoch 71/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.2627 - accuracy: 0.6246 - val_loss: 0.9653 - val_accuracy: 0.6447
# Epoch 72/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.2573 - accuracy: 0.6269 - val_loss: 0.7245 - val_accuracy: 0.7039
# Epoch 73/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0120 - accuracy: 0.6418 - val_loss: 0.5706 - val_accuracy: 0.7829
# Epoch 74/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0823 - accuracy: 0.6296 - val_loss: 0.4936 - val_accuracy: 0.7632
# Epoch 75/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0797 - accuracy: 0.6499 - val_loss: 0.5074 - val_accuracy: 0.7500
# Epoch 76/500
# 18/18 [==============================] - 7s 365ms/step - loss: 1.0847 - accuracy: 0.6852 - val_loss: 0.7844 - val_accuracy: 0.7303
# Epoch 77/500
# 18/18 [==============================] - 7s 366ms/step - loss: 1.2968 - accuracy: 0.6352 - val_loss: 0.4066 - val_accuracy: 0.8224
# Epoch 78/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.2273 - accuracy: 0.6280 - val_loss: 0.5103 - val_accuracy: 0.7566
# Epoch 79/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.7450 - accuracy: 0.5397 - val_loss: 0.8873 - val_accuracy: 0.6842
# Epoch 80/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.5317 - accuracy: 0.5575 - val_loss: 0.5123 - val_accuracy: 0.7566
# Epoch 81/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9691 - accuracy: 0.6533 - val_loss: 0.4638 - val_accuracy: 0.7763
# Epoch 82/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0426 - accuracy: 0.6390 - val_loss: 1.1149 - val_accuracy: 0.7237
# Epoch 83/500
# 18/18 [==============================] - 7s 364ms/step - loss: 1.1680 - accuracy: 0.6757 - val_loss: 0.4614 - val_accuracy: 0.7895
# Epoch 84/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.1090 - accuracy: 0.6190 - val_loss: 0.6918 - val_accuracy: 0.7697
# Epoch 85/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0060 - accuracy: 0.6596 - val_loss: 0.4894 - val_accuracy: 0.7895
# Epoch 86/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.0448 - accuracy: 0.6495 - val_loss: 0.4730 - val_accuracy: 0.7829
# Epoch 87/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.3094 - accuracy: 0.6149 - val_loss: 0.7034 - val_accuracy: 0.7829
# Epoch 88/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.4693 - accuracy: 0.6241 - val_loss: 1.7431 - val_accuracy: 0.5461
# Epoch 89/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.6276 - accuracy: 0.6300 - val_loss: 0.8308 - val_accuracy: 0.7697
# Epoch 90/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.1783 - accuracy: 0.6666 - val_loss: 0.4362 - val_accuracy: 0.8158
# Epoch 91/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.1490 - accuracy: 0.6442 - val_loss: 0.4793 - val_accuracy: 0.7961
# Epoch 92/500
# 18/18 [==============================] - 7s 361ms/step - loss: 0.9041 - accuracy: 0.6699 - val_loss: 0.7485 - val_accuracy: 0.7368
# Epoch 93/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.1606 - accuracy: 0.6553 - val_loss: 0.4299 - val_accuracy: 0.8224
# Epoch 94/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.1443 - accuracy: 0.6444 - val_loss: 0.4323 - val_accuracy: 0.8355
# Epoch 95/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.1120 - accuracy: 0.6608 - val_loss: 0.6857 - val_accuracy: 0.7763
# Epoch 96/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9106 - accuracy: 0.6867 - val_loss: 0.5201 - val_accuracy: 0.7829
# Epoch 97/500
# 18/18 [==============================] - 7s 361ms/step - loss: 0.9615 - accuracy: 0.6850 - val_loss: 0.4605 - val_accuracy: 0.8092
# Epoch 98/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9928 - accuracy: 0.6636 - val_loss: 0.5790 - val_accuracy: 0.7697
# Epoch 99/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.3000 - accuracy: 0.6555 - val_loss: 0.7267 - val_accuracy: 0.7566
# Epoch 100/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.2538 - accuracy: 0.6476 - val_loss: 0.4958 - val_accuracy: 0.7697
# Epoch 101/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0679 - accuracy: 0.6762 - val_loss: 0.4681 - val_accuracy: 0.8224
# Epoch 102/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.0740 - accuracy: 0.6886 - val_loss: 1.4614 - val_accuracy: 0.5724
# Epoch 103/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.3837 - accuracy: 0.6277 - val_loss: 0.5203 - val_accuracy: 0.7829
# Epoch 104/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0250 - accuracy: 0.6479 - val_loss: 0.6930 - val_accuracy: 0.7500
# Epoch 105/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0755 - accuracy: 0.6789 - val_loss: 0.6483 - val_accuracy: 0.7566
# Epoch 106/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.1608 - accuracy: 0.6471 - val_loss: 1.0394 - val_accuracy: 0.6711
# Epoch 107/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1784 - accuracy: 0.6606 - val_loss: 0.9558 - val_accuracy: 0.6711
# Epoch 108/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.1515 - accuracy: 0.6146 - val_loss: 0.4923 - val_accuracy: 0.7895
# Epoch 109/500
# 18/18 [==============================] - 7s 368ms/step - loss: 1.1240 - accuracy: 0.6461 - val_loss: 0.5665 - val_accuracy: 0.7434
# Epoch 110/500
# 18/18 [==============================] - 7s 365ms/step - loss: 0.9019 - accuracy: 0.6735 - val_loss: 0.8035 - val_accuracy: 0.7566
# Epoch 111/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.3568 - accuracy: 0.6564 - val_loss: 0.7260 - val_accuracy: 0.7434
# Epoch 112/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9117 - accuracy: 0.7025 - val_loss: 0.5385 - val_accuracy: 0.7632
# Epoch 113/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.7834 - accuracy: 0.7264 - val_loss: 0.5240 - val_accuracy: 0.7895
# Epoch 114/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.0083 - accuracy: 0.6599 - val_loss: 0.5564 - val_accuracy: 0.7961
# Epoch 115/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.2703 - accuracy: 0.6308 - val_loss: 0.6559 - val_accuracy: 0.7566
# Epoch 116/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0725 - accuracy: 0.6442 - val_loss: 0.5448 - val_accuracy: 0.7829
# Epoch 117/500
# 18/18 [==============================] - 7s 364ms/step - loss: 0.8584 - accuracy: 0.7025 - val_loss: 0.7444 - val_accuracy: 0.7632
# Epoch 118/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.1363 - accuracy: 0.6523 - val_loss: 0.5278 - val_accuracy: 0.8092
# Epoch 119/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.8622 - accuracy: 0.7157 - val_loss: 2.1360 - val_accuracy: 0.5066
# Epoch 120/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.8179 - accuracy: 0.6239 - val_loss: 0.5201 - val_accuracy: 0.7829
# Epoch 121/500
# 18/18 [==============================] - 7s 363ms/step - loss: 0.9270 - accuracy: 0.6938 - val_loss: 0.4311 - val_accuracy: 0.8224
# Epoch 122/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.0453 - accuracy: 0.6577 - val_loss: 0.4448 - val_accuracy: 0.8026
# Epoch 123/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.9125 - accuracy: 0.6652 - val_loss: 1.0085 - val_accuracy: 0.6711
# Epoch 124/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0381 - accuracy: 0.6810 - val_loss: 0.4812 - val_accuracy: 0.7632
# Epoch 125/500
# 18/18 [==============================] - 7s 362ms/step - loss: 0.9474 - accuracy: 0.6827 - val_loss: 0.4622 - val_accuracy: 0.8026
# Epoch 126/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.8884 - accuracy: 0.6844 - val_loss: 0.4746 - val_accuracy: 0.8092
# Epoch 127/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.8800 - accuracy: 0.6975 - val_loss: 0.4664 - val_accuracy: 0.8026
# Epoch 128/500
# 18/18 [==============================] - 7s 365ms/step - loss: 1.0283 - accuracy: 0.6856 - val_loss: 0.6270 - val_accuracy: 0.7434
# Epoch 129/500
# 18/18 [==============================] - 7s 371ms/step - loss: 1.1676 - accuracy: 0.6828 - val_loss: 0.4730 - val_accuracy: 0.7829
# Epoch 130/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.6534 - accuracy: 0.6087 - val_loss: 0.7422 - val_accuracy: 0.7566
# Epoch 131/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.2933 - accuracy: 0.6393 - val_loss: 2.7907 - val_accuracy: 0.4671
# Epoch 132/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.9655 - accuracy: 0.6051 - val_loss: 0.5254 - val_accuracy: 0.8092
# Epoch 133/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.9443 - accuracy: 0.6793 - val_loss: 0.4331 - val_accuracy: 0.8092
# Epoch 134/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.8995 - accuracy: 0.6958 - val_loss: 0.4968 - val_accuracy: 0.7697
# Epoch 135/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.3385 - accuracy: 0.6639 - val_loss: 0.6362 - val_accuracy: 0.7237
# Epoch 136/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.3123 - accuracy: 0.6588 - val_loss: 1.1434 - val_accuracy: 0.6645
# Epoch 137/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0512 - accuracy: 0.6444 - val_loss: 0.4597 - val_accuracy: 0.8158
# Epoch 138/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0377 - accuracy: 0.6769 - val_loss: 0.6161 - val_accuracy: 0.7500
# Epoch 139/500
# 18/18 [==============================] - 7s 357ms/step - loss: 0.9964 - accuracy: 0.6724 - val_loss: 0.6638 - val_accuracy: 0.7368
# Epoch 140/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.0491 - accuracy: 0.6466 - val_loss: 0.5963 - val_accuracy: 0.7632
# Epoch 141/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.1713 - accuracy: 0.6017 - val_loss: 1.1233 - val_accuracy: 0.6842
# Epoch 142/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.7849 - accuracy: 0.6176 - val_loss: 0.4816 - val_accuracy: 0.8158
# Epoch 143/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.5449 - accuracy: 0.6315 - val_loss: 0.8013 - val_accuracy: 0.7237
# Epoch 144/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.9549 - accuracy: 0.6730 - val_loss: 0.7641 - val_accuracy: 0.7039
# Epoch 145/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.2155 - accuracy: 0.6277 - val_loss: 0.4612 - val_accuracy: 0.8092
# Epoch 146/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.2002 - accuracy: 0.6652 - val_loss: 0.6260 - val_accuracy: 0.7763
# Epoch 147/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.2020 - accuracy: 0.6081 - val_loss: 0.4804 - val_accuracy: 0.8092
# Epoch 148/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.5976 - accuracy: 0.5929 - val_loss: 0.7904 - val_accuracy: 0.7237
# Epoch 149/500
# 18/18 [==============================] - 7s 361ms/step - loss: 2.1866 - accuracy: 0.5738 - val_loss: 0.5369 - val_accuracy: 0.7961
# Epoch 150/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0031 - accuracy: 0.7144 - val_loss: 0.8424 - val_accuracy: 0.7171
# Epoch 151/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.5136 - accuracy: 0.6494 - val_loss: 1.5360 - val_accuracy: 0.6842
# Epoch 152/500
# 18/18 [==============================] - 7s 359ms/step - loss: 2.1024 - accuracy: 0.6113 - val_loss: 1.0218 - val_accuracy: 0.6842
# Epoch 153/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.4477 - accuracy: 0.6329 - val_loss: 0.7314 - val_accuracy: 0.7763
# Epoch 154/500
# 18/18 [==============================] - 7s 367ms/step - loss: 1.1624 - accuracy: 0.6918 - val_loss: 0.5296 - val_accuracy: 0.8289
# Epoch 155/500
# 18/18 [==============================] - 7s 366ms/step - loss: 1.1387 - accuracy: 0.6852 - val_loss: 0.6345 - val_accuracy: 0.7368
# Epoch 156/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.1924 - accuracy: 0.6371 - val_loss: 0.5193 - val_accuracy: 0.8026
# Epoch 157/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.0566 - accuracy: 0.6975 - val_loss: 0.5489 - val_accuracy: 0.7961
# Epoch 158/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.0103 - accuracy: 0.6889 - val_loss: 0.5629 - val_accuracy: 0.7632
# Epoch 159/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.8828 - accuracy: 0.6860 - val_loss: 0.5343 - val_accuracy: 0.7895
# Epoch 160/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.8902 - accuracy: 0.7036 - val_loss: 1.2221 - val_accuracy: 0.7105
# Epoch 161/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.3462 - accuracy: 0.6427 - val_loss: 0.5093 - val_accuracy: 0.8092
# Epoch 162/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.9710 - accuracy: 0.6981 - val_loss: 0.6844 - val_accuracy: 0.7368
# Epoch 163/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0110 - accuracy: 0.6788 - val_loss: 0.7128 - val_accuracy: 0.7368
# Epoch 164/500
# 18/18 [==============================] - 7s 363ms/step - loss: 0.9801 - accuracy: 0.7095 - val_loss: 0.5113 - val_accuracy: 0.7697
# Epoch 165/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.0293 - accuracy: 0.6960 - val_loss: 1.6460 - val_accuracy: 0.5921
# Epoch 166/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.2719 - accuracy: 0.6621 - val_loss: 0.5930 - val_accuracy: 0.7961
# Epoch 167/500
# 18/18 [==============================] - 7s 362ms/step - loss: 0.9643 - accuracy: 0.6803 - val_loss: 0.4742 - val_accuracy: 0.8158
# Epoch 168/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.1952 - accuracy: 0.6524 - val_loss: 0.6092 - val_accuracy: 0.7632
# Epoch 169/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0543 - accuracy: 0.6680 - val_loss: 0.7547 - val_accuracy: 0.7237
# Epoch 170/500
# 18/18 [==============================] - 7s 362ms/step - loss: 0.9770 - accuracy: 0.6909 - val_loss: 0.6066 - val_accuracy: 0.7697
# Epoch 171/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.1019 - accuracy: 0.6972 - val_loss: 0.7088 - val_accuracy: 0.7500
# Epoch 172/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.1484 - accuracy: 0.6644 - val_loss: 1.3804 - val_accuracy: 0.6184
# Epoch 173/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.5006 - accuracy: 0.6404 - val_loss: 0.4938 - val_accuracy: 0.8026
# Epoch 174/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.1300 - accuracy: 0.6420 - val_loss: 0.7421 - val_accuracy: 0.7434
# Epoch 175/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.8114 - accuracy: 0.7393 - val_loss: 0.7250 - val_accuracy: 0.7500
# Epoch 176/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1896 - accuracy: 0.6443 - val_loss: 0.9169 - val_accuracy: 0.7237
# Epoch 177/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.0274 - accuracy: 0.6851 - val_loss: 0.9511 - val_accuracy: 0.7303
# Epoch 178/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.1470 - accuracy: 0.6645 - val_loss: 1.2501 - val_accuracy: 0.6908
# Epoch 179/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.5558 - accuracy: 0.6084 - val_loss: 0.4699 - val_accuracy: 0.8158
# Epoch 180/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.2082 - accuracy: 0.6653 - val_loss: 0.9691 - val_accuracy: 0.7039
# Epoch 181/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.2186 - accuracy: 0.6231 - val_loss: 1.6221 - val_accuracy: 0.6118
# Epoch 182/500
# 18/18 [==============================] - 7s 360ms/step - loss: 2.3502 - accuracy: 0.5812 - val_loss: 0.6095 - val_accuracy: 0.7697
# Epoch 183/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.3002 - accuracy: 0.6604 - val_loss: 0.5441 - val_accuracy: 0.7829
# Epoch 184/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.2636 - accuracy: 0.6504 - val_loss: 0.6847 - val_accuracy: 0.7895
# Epoch 185/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.7468 - accuracy: 0.6403 - val_loss: 0.4858 - val_accuracy: 0.8092
# Epoch 186/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.3575 - accuracy: 0.6761 - val_loss: 0.5144 - val_accuracy: 0.7829
# Epoch 187/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.2610 - accuracy: 0.6565 - val_loss: 1.1296 - val_accuracy: 0.6645
# Epoch 188/500
# 18/18 [==============================] - 7s 363ms/step - loss: 1.8219 - accuracy: 0.6342 - val_loss: 0.4738 - val_accuracy: 0.8092
# Epoch 189/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9573 - accuracy: 0.6726 - val_loss: 0.5555 - val_accuracy: 0.7566
# Epoch 190/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1358 - accuracy: 0.6544 - val_loss: 0.6885 - val_accuracy: 0.7500
# Epoch 191/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.8560 - accuracy: 0.7205 - val_loss: 0.5376 - val_accuracy: 0.7763
# Epoch 192/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.9893 - accuracy: 0.6803 - val_loss: 0.5109 - val_accuracy: 0.7961
# Epoch 193/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1085 - accuracy: 0.6752 - val_loss: 0.5825 - val_accuracy: 0.7566
# Epoch 194/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.3261 - accuracy: 0.6555 - val_loss: 0.5165 - val_accuracy: 0.7961
# Epoch 195/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.9603 - accuracy: 0.6777 - val_loss: 0.5695 - val_accuracy: 0.7697
# Epoch 196/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0067 - accuracy: 0.6730 - val_loss: 1.0004 - val_accuracy: 0.7500
# Epoch 197/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0849 - accuracy: 0.6692 - val_loss: 0.7449 - val_accuracy: 0.7368
# Epoch 198/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0394 - accuracy: 0.7037 - val_loss: 0.6568 - val_accuracy: 0.8026
# Epoch 199/500
# 18/18 [==============================] - 7s 362ms/step - loss: 0.9901 - accuracy: 0.6852 - val_loss: 0.5822 - val_accuracy: 0.7566
# Epoch 200/500
# 18/18 [==============================] - 7s 364ms/step - loss: 1.0191 - accuracy: 0.6594 - val_loss: 0.5035 - val_accuracy: 0.8158
# Epoch 201/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9630 - accuracy: 0.6917 - val_loss: 0.5354 - val_accuracy: 0.7895
# Epoch 202/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1741 - accuracy: 0.6362 - val_loss: 0.5434 - val_accuracy: 0.7697
# Epoch 203/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.8851 - accuracy: 0.7241 - val_loss: 0.5008 - val_accuracy: 0.7961
# Epoch 204/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9961 - accuracy: 0.6832 - val_loss: 0.6703 - val_accuracy: 0.7829
# Epoch 205/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.5052 - accuracy: 0.5957 - val_loss: 0.5000 - val_accuracy: 0.7961
# Epoch 206/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.6138 - accuracy: 0.6121 - val_loss: 0.5405 - val_accuracy: 0.7961
# Epoch 207/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0965 - accuracy: 0.6957 - val_loss: 0.5451 - val_accuracy: 0.7697
# Epoch 208/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.8946 - accuracy: 0.6758 - val_loss: 0.5974 - val_accuracy: 0.7697
# Epoch 209/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.3225 - accuracy: 0.6487 - val_loss: 0.4942 - val_accuracy: 0.8026
# Epoch 210/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.0778 - accuracy: 0.7243 - val_loss: 1.2332 - val_accuracy: 0.6711
# Epoch 211/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.6900 - accuracy: 0.5968 - val_loss: 0.5496 - val_accuracy: 0.7566
# Epoch 212/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.3907 - accuracy: 0.6521 - val_loss: 0.4539 - val_accuracy: 0.8224
# Epoch 213/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0068 - accuracy: 0.6884 - val_loss: 0.7237 - val_accuracy: 0.7368
# Epoch 214/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.0838 - accuracy: 0.7061 - val_loss: 0.5338 - val_accuracy: 0.7829
# Epoch 215/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.8174 - accuracy: 0.7215 - val_loss: 0.6854 - val_accuracy: 0.7303
# Epoch 216/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.8935 - accuracy: 0.6806 - val_loss: 0.6191 - val_accuracy: 0.7434
# Epoch 217/500
# 18/18 [==============================] - 7s 365ms/step - loss: 1.0922 - accuracy: 0.6666 - val_loss: 1.5416 - val_accuracy: 0.6316
# Epoch 218/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.2663 - accuracy: 0.6437 - val_loss: 0.5086 - val_accuracy: 0.7697
# Epoch 219/500
# 18/18 [==============================] - 7s 361ms/step - loss: 1.2101 - accuracy: 0.6258 - val_loss: 0.4787 - val_accuracy: 0.8553
# Epoch 220/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.7398 - accuracy: 0.7312 - val_loss: 0.6389 - val_accuracy: 0.7895
# Epoch 221/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.1412 - accuracy: 0.6693 - val_loss: 0.5656 - val_accuracy: 0.8092
# Epoch 222/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.0890 - accuracy: 0.6673 - val_loss: 0.5153 - val_accuracy: 0.7829
# Epoch 223/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.0930 - accuracy: 0.6629 - val_loss: 0.5141 - val_accuracy: 0.7829
# Epoch 224/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.8601 - accuracy: 0.7276 - val_loss: 0.6229 - val_accuracy: 0.7368
# Epoch 225/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.1830 - accuracy: 0.6495 - val_loss: 0.5097 - val_accuracy: 0.8026
# Epoch 226/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.2509 - accuracy: 0.6897 - val_loss: 1.7526 - val_accuracy: 0.5987
# Epoch 227/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.4227 - accuracy: 0.6495 - val_loss: 0.5253 - val_accuracy: 0.8026
# Epoch 228/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.7017 - accuracy: 0.5879 - val_loss: 0.7455 - val_accuracy: 0.7829
# Epoch 229/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.3669 - accuracy: 0.6158 - val_loss: 0.5625 - val_accuracy: 0.7697
# Epoch 230/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.1441 - accuracy: 0.6662 - val_loss: 0.7032 - val_accuracy: 0.7105
# Epoch 231/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0233 - accuracy: 0.6951 - val_loss: 0.5445 - val_accuracy: 0.7829
# Epoch 232/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.1131 - accuracy: 0.6559 - val_loss: 0.6811 - val_accuracy: 0.7039
# Epoch 233/500
# 18/18 [==============================] - 7s 362ms/step - loss: 0.9487 - accuracy: 0.6978 - val_loss: 1.0579 - val_accuracy: 0.7039
# Epoch 234/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.8580 - accuracy: 0.7257 - val_loss: 0.4972 - val_accuracy: 0.8026
# Epoch 235/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.1043 - accuracy: 0.6709 - val_loss: 1.4523 - val_accuracy: 0.6382
# Epoch 236/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.2151 - accuracy: 0.6338 - val_loss: 0.6285 - val_accuracy: 0.7237
# Epoch 237/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.2719 - accuracy: 0.6255 - val_loss: 0.5158 - val_accuracy: 0.7829
# Epoch 238/500
# 18/18 [==============================] - 7s 353ms/step - loss: 0.9866 - accuracy: 0.6612 - val_loss: 1.4365 - val_accuracy: 0.6842
# Epoch 239/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.4399 - accuracy: 0.6658 - val_loss: 0.6470 - val_accuracy: 0.7368
# Epoch 240/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.2446 - accuracy: 0.6773 - val_loss: 0.5598 - val_accuracy: 0.7697
# Epoch 241/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.0939 - accuracy: 0.6638 - val_loss: 0.5907 - val_accuracy: 0.7500
# Epoch 242/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.9892 - accuracy: 0.7116 - val_loss: 1.2656 - val_accuracy: 0.6842
# Epoch 243/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.6294 - accuracy: 0.6040 - val_loss: 0.6999 - val_accuracy: 0.7171
# Epoch 244/500
# 18/18 [==============================] - 7s 351ms/step - loss: 0.9072 - accuracy: 0.7286 - val_loss: 0.7793 - val_accuracy: 0.7763
# Epoch 245/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.2979 - accuracy: 0.6726 - val_loss: 0.6434 - val_accuracy: 0.7171
# Epoch 246/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.3278 - accuracy: 0.6451 - val_loss: 0.5509 - val_accuracy: 0.7829
# Epoch 247/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.9511 - accuracy: 0.6964 - val_loss: 0.5267 - val_accuracy: 0.7961
# Epoch 248/500
# 18/18 [==============================] - 7s 356ms/step - loss: 0.9877 - accuracy: 0.6837 - val_loss: 0.5806 - val_accuracy: 0.8026
# Epoch 249/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.1679 - accuracy: 0.6607 - val_loss: 0.5940 - val_accuracy: 0.7632
# Epoch 250/500
# 18/18 [==============================] - 7s 349ms/step - loss: 1.1314 - accuracy: 0.6839 - val_loss: 0.7979 - val_accuracy: 0.7829
# Epoch 251/500
# 18/18 [==============================] - 7s 348ms/step - loss: 1.0855 - accuracy: 0.6834 - val_loss: 0.4688 - val_accuracy: 0.8421
# Epoch 252/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.9788 - accuracy: 0.6749 - val_loss: 0.7302 - val_accuracy: 0.8026
# Epoch 253/500
# 18/18 [==============================] - 7s 350ms/step - loss: 1.4347 - accuracy: 0.6195 - val_loss: 0.6646 - val_accuracy: 0.7895
# Epoch 254/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.0605 - accuracy: 0.6845 - val_loss: 0.7380 - val_accuracy: 0.7961
# Epoch 255/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.1013 - accuracy: 0.6660 - val_loss: 0.7284 - val_accuracy: 0.7697
# Epoch 256/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.1522 - accuracy: 0.7249 - val_loss: 2.7206 - val_accuracy: 0.4934
# Epoch 257/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.8303 - accuracy: 0.6398 - val_loss: 0.4650 - val_accuracy: 0.8289
# Epoch 258/500
# 18/18 [==============================] - 7s 352ms/step - loss: 0.8586 - accuracy: 0.7182 - val_loss: 0.5158 - val_accuracy: 0.8289
# Epoch 259/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.0216 - accuracy: 0.7083 - val_loss: 0.6027 - val_accuracy: 0.7895
# Epoch 260/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.9752 - accuracy: 0.6752 - val_loss: 0.4579 - val_accuracy: 0.8355
# Epoch 261/500
# 18/18 [==============================] - 7s 353ms/step - loss: 0.9826 - accuracy: 0.6788 - val_loss: 0.4930 - val_accuracy: 0.7763
# Epoch 262/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.9715 - accuracy: 0.6878 - val_loss: 0.6304 - val_accuracy: 0.7434
# Epoch 263/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.9949 - accuracy: 0.6826 - val_loss: 0.5114 - val_accuracy: 0.7895
# Epoch 264/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.1925 - accuracy: 0.6305 - val_loss: 1.5394 - val_accuracy: 0.5987
# Epoch 265/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.0793 - accuracy: 0.6648 - val_loss: 0.6633 - val_accuracy: 0.7895
# Epoch 266/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0592 - accuracy: 0.6601 - val_loss: 1.0403 - val_accuracy: 0.6776
# Epoch 267/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.9537 - accuracy: 0.6875 - val_loss: 0.5169 - val_accuracy: 0.7697
# Epoch 268/500
# 18/18 [==============================] - 7s 351ms/step - loss: 0.9030 - accuracy: 0.7114 - val_loss: 0.6258 - val_accuracy: 0.7303
# Epoch 269/500
# 18/18 [==============================] - 7s 352ms/step - loss: 0.9482 - accuracy: 0.6957 - val_loss: 0.5332 - val_accuracy: 0.7895
# Epoch 270/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.1318 - accuracy: 0.6955 - val_loss: 0.6068 - val_accuracy: 0.8026
# Epoch 271/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.8555 - accuracy: 0.7332 - val_loss: 0.4485 - val_accuracy: 0.8289
# Epoch 272/500
# 18/18 [==============================] - 7s 358ms/step - loss: 0.9357 - accuracy: 0.6768 - val_loss: 0.4510 - val_accuracy: 0.8026
# Epoch 273/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.0817 - accuracy: 0.6558 - val_loss: 0.9201 - val_accuracy: 0.7632
# Epoch 274/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.4804 - accuracy: 0.6638 - val_loss: 0.6619 - val_accuracy: 0.7368
# Epoch 275/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.1685 - accuracy: 0.6833 - val_loss: 0.6067 - val_accuracy: 0.7829
# Epoch 276/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.0657 - accuracy: 0.6635 - val_loss: 0.8727 - val_accuracy: 0.7434
# Epoch 277/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.2820 - accuracy: 0.6660 - val_loss: 0.6556 - val_accuracy: 0.7434
# Epoch 278/500
# 18/18 [==============================] - 7s 353ms/step - loss: 0.8092 - accuracy: 0.7322 - val_loss: 0.4916 - val_accuracy: 0.8289
# Epoch 279/500
# 18/18 [==============================] - 7s 351ms/step - loss: 0.8909 - accuracy: 0.6851 - val_loss: 0.8249 - val_accuracy: 0.6842
# Epoch 280/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.2830 - accuracy: 0.6325 - val_loss: 1.2956 - val_accuracy: 0.6645
# Epoch 281/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.6609 - accuracy: 0.6143 - val_loss: 0.4794 - val_accuracy: 0.8092
# Epoch 282/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.2692 - accuracy: 0.6902 - val_loss: 0.7222 - val_accuracy: 0.7697
# Epoch 283/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.1876 - accuracy: 0.6452 - val_loss: 0.6115 - val_accuracy: 0.7697
# Epoch 284/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.9791 - accuracy: 0.7328 - val_loss: 0.9234 - val_accuracy: 0.6974
# Epoch 285/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.0968 - accuracy: 0.6536 - val_loss: 0.4937 - val_accuracy: 0.7763
# Epoch 286/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.1422 - accuracy: 0.6671 - val_loss: 0.9346 - val_accuracy: 0.7566
# Epoch 287/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.1923 - accuracy: 0.6632 - val_loss: 0.4999 - val_accuracy: 0.8158
# Epoch 288/500
# 18/18 [==============================] - 7s 353ms/step - loss: 0.9465 - accuracy: 0.6886 - val_loss: 0.4283 - val_accuracy: 0.8224
# Epoch 289/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.0821 - accuracy: 0.6668 - val_loss: 1.2057 - val_accuracy: 0.7171
# Epoch 290/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.4397 - accuracy: 0.6487 - val_loss: 0.4891 - val_accuracy: 0.8158
# Epoch 291/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.3020 - accuracy: 0.6974 - val_loss: 0.8382 - val_accuracy: 0.7237
# Epoch 292/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.7338 - accuracy: 0.6178 - val_loss: 0.6226 - val_accuracy: 0.7961
# Epoch 293/500
# 18/18 [==============================] - 7s 356ms/step - loss: 0.9047 - accuracy: 0.7151 - val_loss: 0.4448 - val_accuracy: 0.8092
# Epoch 294/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.1491 - accuracy: 0.6849 - val_loss: 0.6905 - val_accuracy: 0.7434
# Epoch 295/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.0483 - accuracy: 0.7079 - val_loss: 0.4455 - val_accuracy: 0.8224
# Epoch 296/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.8969 - accuracy: 0.7130 - val_loss: 0.4521 - val_accuracy: 0.8158
# Epoch 297/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0425 - accuracy: 0.7039 - val_loss: 0.6085 - val_accuracy: 0.7895
# Epoch 298/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.3098 - accuracy: 0.6418 - val_loss: 0.4744 - val_accuracy: 0.8224
# Epoch 299/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.8249 - accuracy: 0.7566 - val_loss: 0.4690 - val_accuracy: 0.8158
# Epoch 300/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.1241 - accuracy: 0.6734 - val_loss: 0.4410 - val_accuracy: 0.8158
# Epoch 301/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.0970 - accuracy: 0.6724 - val_loss: 1.9611 - val_accuracy: 0.5724
# Epoch 302/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.5826 - accuracy: 0.5954 - val_loss: 0.5366 - val_accuracy: 0.8092
# Epoch 303/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.8311 - accuracy: 0.7484 - val_loss: 0.6572 - val_accuracy: 0.7434
# Epoch 304/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.3470 - accuracy: 0.6621 - val_loss: 0.6098 - val_accuracy: 0.7895
# Epoch 305/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0704 - accuracy: 0.6460 - val_loss: 0.5751 - val_accuracy: 0.7895
# Epoch 306/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.0920 - accuracy: 0.6671 - val_loss: 0.4732 - val_accuracy: 0.8026
# Epoch 307/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.0986 - accuracy: 0.6467 - val_loss: 0.9344 - val_accuracy: 0.6974
# Epoch 308/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.0709 - accuracy: 0.6939 - val_loss: 0.9539 - val_accuracy: 0.7566
# Epoch 309/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.4631 - accuracy: 0.6290 - val_loss: 0.5646 - val_accuracy: 0.7895
# Epoch 310/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.6424 - accuracy: 0.6501 - val_loss: 0.4723 - val_accuracy: 0.8158
# Epoch 311/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0885 - accuracy: 0.6905 - val_loss: 0.7467 - val_accuracy: 0.7763
# Epoch 312/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0250 - accuracy: 0.6865 - val_loss: 0.4655 - val_accuracy: 0.8092
# Epoch 313/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.0477 - accuracy: 0.7267 - val_loss: 1.0992 - val_accuracy: 0.6908
# Epoch 314/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.3023 - accuracy: 0.6799 - val_loss: 0.6959 - val_accuracy: 0.7763
# Epoch 315/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0359 - accuracy: 0.6720 - val_loss: 1.1775 - val_accuracy: 0.7237
# Epoch 316/500
# 18/18 [==============================] - 7s 353ms/step - loss: 2.2394 - accuracy: 0.6091 - val_loss: 1.8569 - val_accuracy: 0.5658
# Epoch 317/500
# 18/18 [==============================] - 7s 353ms/step - loss: 2.0622 - accuracy: 0.6013 - val_loss: 1.1340 - val_accuracy: 0.7303
# Epoch 318/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.7015 - accuracy: 0.6453 - val_loss: 0.9409 - val_accuracy: 0.7434
# Epoch 319/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.7037 - accuracy: 0.6209 - val_loss: 0.5355 - val_accuracy: 0.8224
# Epoch 320/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.1780 - accuracy: 0.6855 - val_loss: 0.7871 - val_accuracy: 0.7434
# Epoch 321/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.4279 - accuracy: 0.6560 - val_loss: 0.5369 - val_accuracy: 0.7632
# Epoch 322/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.1348 - accuracy: 0.6733 - val_loss: 0.4687 - val_accuracy: 0.8224
# Epoch 323/500
# 18/18 [==============================] - 7s 351ms/step - loss: 0.9887 - accuracy: 0.6974 - val_loss: 0.5114 - val_accuracy: 0.7895
# Epoch 324/500
# 18/18 [==============================] - 7s 350ms/step - loss: 1.2419 - accuracy: 0.6536 - val_loss: 1.0925 - val_accuracy: 0.6974
# Epoch 325/500
# 18/18 [==============================] - 7s 350ms/step - loss: 1.4394 - accuracy: 0.6084 - val_loss: 0.5629 - val_accuracy: 0.7961
# Epoch 326/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.1783 - accuracy: 0.6805 - val_loss: 0.6481 - val_accuracy: 0.7895
# Epoch 327/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.0359 - accuracy: 0.7139 - val_loss: 0.7660 - val_accuracy: 0.7303
# Epoch 328/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0668 - accuracy: 0.6781 - val_loss: 0.5845 - val_accuracy: 0.7829
# Epoch 329/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.4312 - accuracy: 0.6054 - val_loss: 0.5463 - val_accuracy: 0.8026
# Epoch 330/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.5034 - accuracy: 0.6313 - val_loss: 0.6265 - val_accuracy: 0.7763
# Epoch 331/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0848 - accuracy: 0.6957 - val_loss: 0.8350 - val_accuracy: 0.7105
# Epoch 332/500
# ...
# Epoch 391/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.3416 - accuracy: 0.6680 - val_loss: 0.8414 - val_accuracy: 0.7895
# Epoch 392/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.2608 - accuracy: 0.6671 - val_loss: 0.7448 - val_accuracy: 0.7237
# Epoch 393/500
# 18/18 [==============================] - 7s 351ms/step - loss: 0.9499 - accuracy: 0.7250 - val_loss: 0.5578 - val_accuracy: 0.7763
# Epoch 394/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.1837 - accuracy: 0.6942 - val_loss: 0.7421 - val_accuracy: 0.7171
# Epoch 395/500
# 18/18 [==============================] - 7s 350ms/step - loss: 1.3167 - accuracy: 0.6403 - val_loss: 0.9211 - val_accuracy: 0.7632
# Epoch 396/500
# 18/18 [==============================] - 7s 350ms/step - loss: 1.5619 - accuracy: 0.6629 - val_loss: 0.8255 - val_accuracy: 0.7171
# Epoch 397/500
# 18/18 [==============================] - 7s 348ms/step - loss: 1.0071 - accuracy: 0.7145 - val_loss: 0.8690 - val_accuracy: 0.7632
# Epoch 398/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.7491 - accuracy: 0.6275 - val_loss: 0.6637 - val_accuracy: 0.7566
# Epoch 399/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.1765 - accuracy: 0.6806 - val_loss: 0.4946 - val_accuracy: 0.8026
# Epoch 400/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.0898 - accuracy: 0.6952 - val_loss: 1.1430 - val_accuracy: 0.7303
# Epoch 401/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.5442 - accuracy: 0.6646 - val_loss: 0.7074 - val_accuracy: 0.7500
# Epoch 402/500
# 18/18 [==============================] - 7s 355ms/step - loss: 0.9447 - accuracy: 0.7270 - val_loss: 0.8978 - val_accuracy: 0.7237
# Epoch 403/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.0720 - accuracy: 0.6811 - val_loss: 0.6197 - val_accuracy: 0.7566
# Epoch 404/500
# 18/18 [==============================] - 7s 356ms/step - loss: 0.9970 - accuracy: 0.7081 - val_loss: 0.5619 - val_accuracy: 0.7895
# Epoch 405/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0415 - accuracy: 0.7025 - val_loss: 0.7415 - val_accuracy: 0.8092
# Epoch 406/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.0519 - accuracy: 0.6981 - val_loss: 0.5497 - val_accuracy: 0.7895
# Epoch 407/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0036 - accuracy: 0.7170 - val_loss: 0.9292 - val_accuracy: 0.6974
# Epoch 408/500
# 18/18 [==============================] - 7s 353ms/step - loss: 0.9519 - accuracy: 0.6930 - val_loss: 0.8496 - val_accuracy: 0.7829
# Epoch 409/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.3564 - accuracy: 0.6416 - val_loss: 0.9541 - val_accuracy: 0.7105
# Epoch 410/500
# 18/18 [==============================] - 7s 356ms/step - loss: 0.9714 - accuracy: 0.7350 - val_loss: 0.6162 - val_accuracy: 0.7895
# Epoch 411/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.0733 - accuracy: 0.6868 - val_loss: 0.6452 - val_accuracy: 0.7566
# Epoch 412/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.9432 - accuracy: 0.6974 - val_loss: 0.5540 - val_accuracy: 0.7763
# Epoch 413/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0326 - accuracy: 0.6842 - val_loss: 0.6692 - val_accuracy: 0.7697
# Epoch 414/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0831 - accuracy: 0.7272 - val_loss: 0.8806 - val_accuracy: 0.7105
# Epoch 415/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.0226 - accuracy: 0.7152 - val_loss: 0.6566 - val_accuracy: 0.7895
# Epoch 416/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.0332 - accuracy: 0.7042 - val_loss: 0.5893 - val_accuracy: 0.7566
# Epoch 417/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.9532 - accuracy: 0.6806 - val_loss: 0.6005 - val_accuracy: 0.7500
# Epoch 418/500
# 18/18 [==============================] - 7s 352ms/step - loss: 0.8416 - accuracy: 0.7519 - val_loss: 0.5314 - val_accuracy: 0.7895
# Epoch 419/500
# 18/18 [==============================] - 7s 352ms/step - loss: 0.8150 - accuracy: 0.7085 - val_loss: 0.5592 - val_accuracy: 0.7895
# Epoch 420/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.1443 - accuracy: 0.6645 - val_loss: 0.6742 - val_accuracy: 0.7763
# Epoch 421/500
# 18/18 [==============================] - 7s 350ms/step - loss: 1.6185 - accuracy: 0.6229 - val_loss: 0.5599 - val_accuracy: 0.7697
# Epoch 422/500
# 18/18 [==============================] - 7s 351ms/step - loss: 0.9470 - accuracy: 0.7035 - val_loss: 0.5249 - val_accuracy: 0.7763
# Epoch 423/500
# 18/18 [==============================] - 7s 353ms/step - loss: 0.9829 - accuracy: 0.6770 - val_loss: 0.5156 - val_accuracy: 0.7763
# Epoch 424/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.1467 - accuracy: 0.6844 - val_loss: 0.8451 - val_accuracy: 0.7303
# Epoch 425/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.2323 - accuracy: 0.6731 - val_loss: 0.5373 - val_accuracy: 0.7895
# Epoch 426/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.9592 - accuracy: 0.6993 - val_loss: 0.5491 - val_accuracy: 0.7829
# Epoch 427/500
# 18/18 [==============================] - 7s 357ms/step - loss: 0.9171 - accuracy: 0.6888 - val_loss: 0.6806 - val_accuracy: 0.7632
# Epoch 428/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.0393 - accuracy: 0.6931 - val_loss: 0.9998 - val_accuracy: 0.7632
# Epoch 429/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.1723 - accuracy: 0.7167 - val_loss: 0.5585 - val_accuracy: 0.7829
# Epoch 430/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.0621 - accuracy: 0.6836 - val_loss: 0.6398 - val_accuracy: 0.7632
# Epoch 431/500
# 18/18 [==============================] - 7s 359ms/step - loss: 0.9897 - accuracy: 0.6962 - val_loss: 0.6203 - val_accuracy: 0.7697
# Epoch 432/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.1057 - accuracy: 0.7140 - val_loss: 1.9409 - val_accuracy: 0.6974
# Epoch 433/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.9608 - accuracy: 0.6106 - val_loss: 1.8565 - val_accuracy: 0.5658
# Epoch 434/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.5326 - accuracy: 0.6344 - val_loss: 0.8084 - val_accuracy: 0.7105
# Epoch 435/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.1474 - accuracy: 0.6633 - val_loss: 1.3778 - val_accuracy: 0.7303
# Epoch 436/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.2876 - accuracy: 0.7005 - val_loss: 0.7882 - val_accuracy: 0.7171
# Epoch 437/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.2409 - accuracy: 0.6913 - val_loss: 0.6385 - val_accuracy: 0.7961
# Epoch 438/500
# 18/18 [==============================] - 7s 353ms/step - loss: 2.2176 - accuracy: 0.6484 - val_loss: 2.5318 - val_accuracy: 0.5395
# Epoch 439/500
# 18/18 [==============================] - 7s 358ms/step - loss: 2.0275 - accuracy: 0.6195 - val_loss: 1.1585 - val_accuracy: 0.7303
# Epoch 440/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.3507 - accuracy: 0.7003 - val_loss: 1.1760 - val_accuracy: 0.6776
# Epoch 441/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.6216 - accuracy: 0.6332 - val_loss: 0.5133 - val_accuracy: 0.8224
# Epoch 442/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.9898 - accuracy: 0.7261 - val_loss: 0.6277 - val_accuracy: 0.7500
# Epoch 443/500
# 18/18 [==============================] - 7s 353ms/step - loss: 0.9892 - accuracy: 0.7076 - val_loss: 0.5365 - val_accuracy: 0.8026
# Epoch 444/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.5104 - accuracy: 0.6495 - val_loss: 0.5293 - val_accuracy: 0.8158
# Epoch 445/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.4204 - accuracy: 0.6862 - val_loss: 0.5213 - val_accuracy: 0.8092
# Epoch 446/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.0222 - accuracy: 0.7050 - val_loss: 0.8297 - val_accuracy: 0.7763
# Epoch 447/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.2177 - accuracy: 0.6983 - val_loss: 0.6805 - val_accuracy: 0.7632
# Epoch 448/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.3764 - accuracy: 0.6660 - val_loss: 0.9137 - val_accuracy: 0.7697
# Epoch 449/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.4248 - accuracy: 0.7027 - val_loss: 1.0872 - val_accuracy: 0.6908
# Epoch 450/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.4283 - accuracy: 0.6724 - val_loss: 0.5106 - val_accuracy: 0.8224
# Epoch 451/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1263 - accuracy: 0.6568 - val_loss: 0.5544 - val_accuracy: 0.8026
# Epoch 452/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0478 - accuracy: 0.6775 - val_loss: 1.6859 - val_accuracy: 0.6382
# Epoch 453/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.9180 - accuracy: 0.6025 - val_loss: 0.6596 - val_accuracy: 0.7895
# Epoch 454/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.0968 - accuracy: 0.7023 - val_loss: 0.5869 - val_accuracy: 0.8092
# Epoch 455/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0974 - accuracy: 0.6684 - val_loss: 0.5629 - val_accuracy: 0.8026
# Epoch 456/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.9353 - accuracy: 0.6923 - val_loss: 0.6011 - val_accuracy: 0.7961
# Epoch 457/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0160 - accuracy: 0.6998 - val_loss: 1.1190 - val_accuracy: 0.7566
# Epoch 458/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.3249 - accuracy: 0.6818 - val_loss: 0.6977 - val_accuracy: 0.7632
# Epoch 459/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.1137 - accuracy: 0.6904 - val_loss: 0.6723 - val_accuracy: 0.7763
# Epoch 460/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.2555 - accuracy: 0.6305 - val_loss: 0.5898 - val_accuracy: 0.8026
# Epoch 461/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.3570 - accuracy: 0.6900 - val_loss: 0.5450 - val_accuracy: 0.7763
# Epoch 462/500
# 18/18 [==============================] - 7s 357ms/step - loss: 1.4426 - accuracy: 0.6551 - val_loss: 1.0948 - val_accuracy: 0.7171
# Epoch 463/500
# 18/18 [==============================] - 7s 362ms/step - loss: 1.8008 - accuracy: 0.6318 - val_loss: 0.7084 - val_accuracy: 0.7368
# Epoch 464/500
# 18/18 [==============================] - 7s 353ms/step - loss: 2.0122 - accuracy: 0.5997 - val_loss: 0.6136 - val_accuracy: 0.7632
# Epoch 465/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0467 - accuracy: 0.6960 - val_loss: 0.9618 - val_accuracy: 0.6776
# Epoch 466/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.1197 - accuracy: 0.6910 - val_loss: 0.6098 - val_accuracy: 0.7763
# Epoch 467/500
# 18/18 [==============================] - 7s 354ms/step - loss: 0.8118 - accuracy: 0.7487 - val_loss: 0.5755 - val_accuracy: 0.8092
# Epoch 468/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.1463 - accuracy: 0.6133 - val_loss: 0.5512 - val_accuracy: 0.7961
# Epoch 469/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.0769 - accuracy: 0.7113 - val_loss: 0.5059 - val_accuracy: 0.8421
# Epoch 470/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.2158 - accuracy: 0.6698 - val_loss: 0.5075 - val_accuracy: 0.8158
# Epoch 471/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0842 - accuracy: 0.7129 - val_loss: 0.8019 - val_accuracy: 0.6974
# Epoch 472/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.2463 - accuracy: 0.6866 - val_loss: 1.4064 - val_accuracy: 0.6579
# Epoch 473/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.0380 - accuracy: 0.7213 - val_loss: 0.5567 - val_accuracy: 0.7632
# Epoch 474/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.1560 - accuracy: 0.6630 - val_loss: 0.5720 - val_accuracy: 0.7895
# Epoch 475/500
# 18/18 [==============================] - 7s 360ms/step - loss: 0.9196 - accuracy: 0.7395 - val_loss: 0.7915 - val_accuracy: 0.7829
# Epoch 476/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.2888 - accuracy: 0.6791 - val_loss: 0.5674 - val_accuracy: 0.7632
# Epoch 477/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.0133 - accuracy: 0.7118 - val_loss: 0.5558 - val_accuracy: 0.7895
# Epoch 478/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.0891 - accuracy: 0.6879 - val_loss: 0.7795 - val_accuracy: 0.7763
# Epoch 479/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.0542 - accuracy: 0.7035 - val_loss: 0.7847 - val_accuracy: 0.7368
# Epoch 480/500
# 18/18 [==============================] - 7s 350ms/step - loss: 0.8792 - accuracy: 0.7395 - val_loss: 0.9486 - val_accuracy: 0.7632
# Epoch 481/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.3195 - accuracy: 0.6483 - val_loss: 0.6526 - val_accuracy: 0.7829
# Epoch 482/500
# 18/18 [==============================] - 7s 352ms/step - loss: 1.2985 - accuracy: 0.6752 - val_loss: 1.1100 - val_accuracy: 0.6908
# Epoch 483/500
# 18/18 [==============================] - 7s 351ms/step - loss: 1.3407 - accuracy: 0.6696 - val_loss: 1.8128 - val_accuracy: 0.6053
# Epoch 484/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.7231 - accuracy: 0.6488 - val_loss: 1.3000 - val_accuracy: 0.7237
# Epoch 485/500
# 18/18 [==============================] - 7s 353ms/step - loss: 1.8704 - accuracy: 0.6384 - val_loss: 0.6974 - val_accuracy: 0.7697
# Epoch 486/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0235 - accuracy: 0.6880 - val_loss: 0.5720 - val_accuracy: 0.7895
# Epoch 487/500
# 18/18 [==============================] - 7s 358ms/step - loss: 1.2160 - accuracy: 0.6857 - val_loss: 0.5599 - val_accuracy: 0.7829
# Epoch 488/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0431 - accuracy: 0.7102 - val_loss: 1.0891 - val_accuracy: 0.7434
# Epoch 489/500
# 18/18 [==============================] - 7s 360ms/step - loss: 1.6269 - accuracy: 0.6135 - val_loss: 0.5827 - val_accuracy: 0.8158
# Epoch 490/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.2684 - accuracy: 0.6750 - val_loss: 1.4646 - val_accuracy: 0.6513
# Epoch 491/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.2184 - accuracy: 0.6740 - val_loss: 0.8634 - val_accuracy: 0.7303
# Epoch 492/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.3778 - accuracy: 0.6365 - val_loss: 0.5782 - val_accuracy: 0.7829
# Epoch 493/500
# 18/18 [==============================] - 7s 359ms/step - loss: 1.1858 - accuracy: 0.6872 - val_loss: 0.7389 - val_accuracy: 0.7829
# Epoch 494/500
# 18/18 [==============================] - 7s 352ms/step - loss: 0.9030 - accuracy: 0.7372 - val_loss: 0.5762 - val_accuracy: 0.8158
# Epoch 495/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.3490 - accuracy: 0.6986 - val_loss: 1.1253 - val_accuracy: 0.6908
# Epoch 496/500
# 18/18 [==============================] - 7s 355ms/step - loss: 1.4404 - accuracy: 0.6694 - val_loss: 0.5289 - val_accuracy: 0.8158
# Epoch 497/500
# 18/18 [==============================] - 7s 351ms/step - loss: 0.8155 - accuracy: 0.7537 - val_loss: 0.5307 - val_accuracy: 0.7961
# Epoch 498/500
# 18/18 [==============================] - 7s 354ms/step - loss: 1.0603 - accuracy: 0.7083 - val_loss: 0.7340 - val_accuracy: 0.7566
# Epoch 499/500
# 18/18 [==============================] - 7s 356ms/step - loss: 1.0658 - accuracy: 0.7175 - val_loss: 1.3314 - val_accuracy: 0.6579
# Epoch 500/500
# 18/18 [==============================] - 7s 351ms/step - loss: 0.9496 - accuracy: 0.7155 - val_loss: 0.8001 - val_accuracy: 0.7434

# %%
# Save Model and Weights
model.save('resnet50_ct.h5')
model.save_weights('resnet50_weights_ct.hdf5')

# %%
import tensorflow as tf
from tensorflow import keras
tf.keras.models.save_model(model, '/content/drive/MyDrive/COVID/resnet50_ct.h5')

# %%
# Load saved model
model = load_model('/content/drive/MyDrive/COVID/resnet50_ct.h5')

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% COVID')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% NonCOVID')
  plt.style.reload_library
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.93      0.77        70
#            1       0.91      0.59      0.71        82
#
#     accuracy                           0.74       152
#    macro avg       0.78      0.76      0.74       152
# weighted avg       0.79      0.74      0.74       152

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('resnet50_ct_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('resnet50_ct_loss.png')
plt.show()

# %%
#ACCURACY
from sklearn.metrics import accuracy_score
print('Accuracy score:' , accuracy_score(y_test_bin, y_pred_bin))
# Out:
# Accuracy score: 0.743421052631579
